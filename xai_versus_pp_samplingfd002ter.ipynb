# %%
from __future__ import print_function
import pandas as pd
import matplotlib.pyplot as plt

from lime.lime_tabular import RecurrentTabularExplainer
from tqdm import tqdm
import keras
from sp_modif.model_function import *
from sp_modif.methods import *
from sp_modif.data_prep import *
from sp_modif.evaluator import *
from sp_modif.SHAP import *
from sp_modif.L2X import *
import warnings

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import random
# import keras
import math

from sklearn.metrics import mean_squared_error, r2_score 
from sklearn.model_selection import GroupKFold
from sklearn import preprocessing
from keras import backend as K
from sklearn.preprocessing import MinMaxScaler , StandardScaler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Activation, GRU
from scipy import optimize
from methods import *
import warnings
from tensorflow.keras import optimizers
warnings.filterwarnings("ignore")
# %matplotlib inline

warnings.filterwarnings('ignore')
print("okay")
# Out:
# WARNING:tensorflow:From c:\ProgramData\anaconda3\envs\tensorflow_env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# okay

# %%
SEED = 0
def set_seed(seed=SEED):
    os.environ['PYTHONHASHSEED'] = str(SEED)
    random.seed(SEED)
    np.random.seed(SEED)
    tf.random.set_seed(SEED)

# Appeler la fonction pour fixer le seed
set_seed(SEED)

# %%
# Function to generate explanations
# Function explanation for lime

def get_lime_explanation(data, e, L2X=False) :
    # e  = fn = model.predict
    # Iniatialisation
    df_expplanation = pd.DataFrame(columns=[str(i) for i in range(data.shape[1]*data.shape[2])])

    # Get explanations
    for row in range(data.shape[0]) : 
        explanation = lime_explainer.explain_instance(data[row],
                                                      e,
                                                      num_features=data.shape[1]*data.shape[2]) 
        # fn = model.predict, initialize lime_explainer = Reccurent()
        lime_values = explanation.local_exp[1]
        # Add explanation in df_explanation
        lime_dict = {}
        for tup in lime_values :
            lime_dict[str(tup[0])] = tup[1]
        df_expplanation.loc[len(df_expplanation)] = lime_dict
    
    return df_expplanation

# # Function explanation for others
def get_explainations(data, e, L2X = False) :
    
    # df diemnsion
    if L2X==True :
        X_to_def_col = data[0:1]
        explanation_test = e.explain(X_to_def_col.reshape((X_to_def_col.shape[0], -1)))
        num_columns = explanation_test.flatten().shape[0]
        
    else : 
        explanation_test = e.explain(data[0:1])
        num_columns = explanation_test.flatten().shape[0]
    
    # Iniatialisation
    df_expplanation = pd.DataFrame(columns=[str(i) for i in range(num_columns)])

    # Get explanations
    for row in range(data.shape[0]) :
        if L2X==True:
            X_row = data[row:row+1]
            explanation = e.explain(X_row.reshape((X_row.shape[0], -1)))
        else :
            explanation = e.explain(data[row:row+1])
        # Add explanation in df_explanation
        explanation = explanation.flatten()
        feature_dict = {}
        for i in range(num_columns) :
            feature_dict[str(i)] = explanation[i]
        df_expplanation.loc[len(df_expplanation)] = feature_dict
    
    return df_expplanation

# %% [markdown]
# ### FD002

# %%
# Load data and preprocess
with tf.device('/device:GPU:1'):
    train, test, y_test = prepare_data('FD002.txt')
    print(train.shape, test.shape, y_test.shape)
    sensor_names = ['T20','T24','T30','T50','P20','P15','P30','Nf','Nc','epr','Ps30','phi',
                    'NRf','NRc','BPR','farB','htBleed','Nf_dmd','PCNfR_dmd','W31','W32']

    remaining_sensors = ['T24','T30','T50','P30','Nf','Nc','Ps30','phi',
                    'NRf','NRc','BPR','htBleed','W31','W32'] # selection based on main_notebook

    drop_sensors = [element for element in sensor_names if element not in remaining_sensors]
# Out:
# (53759, 27) (33991, 26) (259, 1)

# %%
def model002(input_shape,weights_file):
    '''
    node = 64, activation = tanh, dropout = 0.2, bs = 128
    '''

    nodes_per_layer = 64
    activation_value= 'tanh'
    dropout = 0.2
    bs = 128


    cb = keras.callbacks.EarlyStopping(monitor='loss', patience=4)
    model = Sequential()
    model.add(LSTM(nodes_per_layer, activation=activation_value, input_shape=input_shape))
    model.add(Dropout(dropout))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error',
                  optimizer=Adam(learning_rate=0.001))
    model.save_weights(weights_file)
    return model

# %%
from tqdm import tqdm
sequence_lengths = [30, 35, 38, 39, 40]
list_alpha = [0.2, 0.3, 0.5]
list_upper = [120,125,130]
metrics_names = ['identity', 'separability', 'stability', 'coherence', 'completness', 'congruence',
                 'selectivity', 'accumen',	'Verm_stability',	'fidelity',	'sparsity', 'instability']
                     
df_metrics = pd.DataFrame()
results = pd.DataFrame()
# all_list = [(seq, alpha, upper) for seq in sequence_lengths for alpha in list_alpha for rec_rul in list_upper]
all_list = []
for sq in sequence_lengths:
    for alpha in list_alpha:
        for upper in list_upper:
            triplet = (sq, alpha, upper)
            all_list.append(triplet)
list_d = []
list_df_metric = []
df_metrics = pd.DataFrame()
results = pd.DataFrame()

for elm in tqdm(all_list[35:]):
    # Modeling
    print(elm)
    print('...')
    sequence_length = elm[0]
    alpha = elm[1]
    upper = elm[2]
    
    learning_rate_ = 0.001
    dropout = 0.2
    activation = 'tanh'
    epochs = 20
    batch_size = 128
    train = rul_piecewise_fct(train, upper)

    #Model creation
    weights_file = "fd002_result/" + str(alpha) + '1lstm_hyper_parameter_weights.h5'
    input_shape = (sequence_length, len(remaining_sensors))
    model = model002(input_shape, weights_file)
    
    # Data prepration
    X_train_interim, X_test_interim = prep_data(train, test, drop_sensors, remaining_sensors, alpha)

    # create sequences train, test
    train_array = gen_data_wrapper(X_train_interim, sequence_length,remaining_sensors)
    label_array = gen_label_wrapper(X_train_interim, sequence_length, ['RUL'])

    test_gen = (list(gen_test_data(X_test_interim[X_test_interim['Unit']==unit_nr], sequence_length,remaining_sensors, -99.))
               for unit_nr in X_test_interim['Unit'].unique())
    
    test_array = np.concatenate(list(test_gen)).astype(np.float32)
    test_rul = rul_piecewise_fct(y_test,upper)
    print(train_array.shape, label_array.shape, test_array.shape)
    
    mse_val = []
    R2_val = []
    RMSE = []
    score_val = []
    mse = []
    # Model fitting
    with tf.device('/device:GPU:1'):
        history = model.fit(train_array, label_array,
                                validation_data=(test_array, test_rul),
                                epochs=epochs,
                                batch_size=batch_size,
                                # callbacks=[cb],
                                verbose=0)
        mse.append(history.history['val_loss'][-1])

        y_hat_val_split = model.predict(test_array)
        R2_val.append(r2_score(test_rul, y_hat_val_split))
        RMSE.append(np.sqrt(mean_squared_error(test_rul, y_hat_val_split)))
        score_val.append(compute_s_score(test_rul, y_hat_val_split))
            
        
    #  append results
    d = {'RMSE' :np.mean(RMSE), 'std_RMSE' :np.std(RMSE),
         'S_score' :np.mean(score_val), 'std_S_score' :np.std(score_val),
         'MSE':np.mean(mse), 'std_MSE':np.std(mse),
        #  'nodes':str(nodes_per_layer),
         'dropout':dropout, 
         'activation':activation, 'batch_size':batch_size}

#     results = results.append(pd.DataFrame(d, index=[0]), ignore_index=True)
    results = pd.concat([results, pd.DataFrame(d, index=[0])], ignore_index=True)
    results.to_csv('fd002_result/performance_by_layerl48.csv')
     
        
    # Get explanation and calculate the score
    
    with tf.device('/device:GPU:1'):  
        for rd in range(5):
        
                # Get explanation and calculate the score
                # Echantillonage
                n_individus = test_array.shape[0]

                # # Choisir aléatoirement 5 indices d'individus
                np.random.seed(rd)
                indices_choisis = np.random.choice(n_individus, size=5, replace=False)

                # Sélectionner les données correspondant aux indices choisis
                test_array_sampling = test_array[indices_choisis, :, :]
                label_array_sampling = y_test.values[indices_choisis, :]

                # Afficher les dimensions des données sélectionnées
                print(test_array_sampling.shape, label_array_sampling.shape)
                
                # distance matrix XX'
                X_dist = pd.DataFrame(squareform(pdist(test_array_sampling.reshape((test_array_sampling.shape[0], -1)))))

                # LIME
                lime_explainer = RecurrentTabularExplainer(test_array, training_labels=label_array,
                                                                feature_names=remaining_sensors,
                                                                mode = 'regression',
                                                                )
                lime_values = get_lime_explanation(test_array_sampling, e = model.predict)
                lime_values.shape
                Lime_dist = pd.DataFrame(squareform(pdist(lime_values))) # Lime values explanation matrix

                #Lime's metrics
                list_metrics_lime = {}
                list_metrics_lime['identity'] = identity(X_dist, Lime_dist)
                list_metrics_lime['separability'] = separability(X_dist, Lime_dist)
                list_metrics_lime['stability'] = stability(X_dist, Lime_dist)
                list_metrics_lime['coherence'], list_metrics_lime['completness'], list_metrics_lime['congruence'] = coherence(model=model.predict, 
                                                                explainer = get_lime_explanation,
                                                            samples=test_array_sampling,
                                                                targets=label_array, e = model.predict)
                list_metrics_lime['selectivity'] = selectivity(model=model.predict, explainer = get_lime_explanation,
                                                            samples=test_array_sampling, e_x = model.predict)
                list_metrics_lime['accumen'] = acumen(get_lime_explanation, test_array_sampling, e=model.predict)
                list_metrics_lime['Verm_stability'] = stability_Velmurugan(get_lime_explanation, test_array_sampling,
                                                                            e=model.predict, top_features=200)
                list_metrics_lime['fidelity'], list_metrics_lime['sparsity'] = fidelity(model=model.predict, 
                                                                explainer = get_lime_explanation,
                                                                samples=test_array_sampling,
                                                                e = model.predict, L2X=True)
                list_metrics_lime['instability'] = instability(model=model.predict, 
                                                                explainer = get_lime_explanation,
                                                                samples=test_array_sampling,
                                                                e = model.predict, L2X=True)
                
                list_metrics_lime['alpha'] = alpha
                list_metrics_lime['upper'] = upper
                list_metrics_lime['sequence_length'] = sequence_length
                list_metrics_lime['explainer'] = 'lime'
                # list_metrics_lime['model'] = model_name

                df_metrics = pd.concat([df_metrics, pd.DataFrame([list_metrics_lime])])

                # SHAP
                e = KernelSHAP(model)
                shapvalues = get_explainations(test_array_sampling, e)
                shapvalues.shape

                list_metrics_shap = {}
                shap_dist = pd.DataFrame(squareform(pdist(shapvalues))) # shap values explanation matrix

                list_metrics_shap['identity'] = identity(X_dist, shap_dist)
                list_metrics_shap['separability'] = separability(X_dist, shap_dist)
                list_metrics_shap['stability'] = stability(X_dist, shap_dist)
                list_metrics_shap['coherence'], list_metrics_shap['completness'], list_metrics_shap['congruence'] = coherence(model=model.predict, 
                                                                explainer = get_explainations,
                                                            samples=test_array_sampling,
                                                                targets=label_array, e = e)
                list_metrics_shap['selectivity'] = selectivity(model=model.predict, explainer = get_explainations,
                                                samples=test_array_sampling, e_x=e)
                list_metrics_shap['accumen'] = acumen(get_explainations, test_array_sampling, e=e)
                list_metrics_shap['Verm_stability'] = stability_Velmurugan(get_explainations, test_array_sampling,
                                                                            e=e, top_features=200)
                list_metrics_shap['fidelity'], list_metrics_shap['sparsity']= fidelity(model=model.predict, 
                                                                explainer = get_explainations,
                                                                samples=test_array_sampling,
                                                                e = e)
                list_metrics_shap['instability']= instability(model=model.predict, 
                                                                explainer = get_explainations,
                                                                samples=test_array_sampling,
                                                                e = e)
                
                list_metrics_shap['alpha'] = alpha
                list_metrics_shap['upper'] = upper
                list_metrics_shap['sequence_length'] = sequence_length
                list_metrics_shap['explainer'] = 'shap'
                # list_metrics_shap['model'] = model_name

                df_metrics = pd.concat([df_metrics, pd.DataFrame([list_metrics_shap])])
                
                # L2X
                e = L2X(model.predict, test_array_sampling)
                l2xvalues = get_explainations(test_array_sampling, e, L2X=True)
                l2xvalues.shape

                # L2X's metrics
                list_metrics_l2x = {}
                l2x_dist = pd.DataFrame(squareform(pdist(l2xvalues))) # Lime values explanation matrix

                list_metrics_l2x['identity'] = identity(X_dist, l2x_dist)
                list_metrics_l2x['separability'] = separability(X_dist, l2x_dist)
                list_metrics_l2x['stability'] = stability(X_dist, l2x_dist)
                list_metrics_l2x['coherence'], list_metrics_l2x['completness'], list_metrics_l2x['congruence'] = coherence(model=model.predict, explainer = get_explainations,
                                                            samples=test_array_sampling, targets=label_array_sampling, e = e, L2X=True)
                list_metrics_l2x['selectivity'] = selectivity(model=model.predict, explainer = get_explainations,
                                                samples=test_array_sampling, e_x=e, L2X=True)
                list_metrics_l2x['accumen'] = acumen(get_explainations, test_array_sampling, e=e, L2X=True)
                list_metrics_l2x['Verm_stability'] = stability_Velmurugan(get_explainations, test_array_sampling,
                                                                            e=e, top_features=200, L2X=True)
                list_metrics_l2x['fidelity'], list_metrics_l2x['sparsity']= fidelity(model=model.predict, 
                                                                explainer = get_explainations,
                                                                samples=test_array_sampling,
                                                                e = e, L2X=True)
                list_metrics_l2x['instability'] = instability(model=model.predict, 
                                                                explainer = get_explainations,
                                                                samples=test_array_sampling,
                                                                e = e, L2X=True)
                
                list_metrics_l2x['alpha'] = alpha
                list_metrics_l2x['upper'] = upper
                list_metrics_l2x['sequence_length'] = sequence_length
                list_metrics_l2x['explainer'] = 'l2x'
                # list_metrics_l2x['model'] = model_name


                df_metrics = pd.concat([df_metrics, pd.DataFrame([list_metrics_l2x])])
    df_metrics.to_csv('fd002_result/quality_by_layerl48.csv')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# (39, 0.5, 130)
# ...
# WARNING:tensorflow:From c:\ProgramData\anaconda3\envs\tensorflow_env\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# (43879, 39, 14) (43879, 1) (259, 39, 14)
# WARNING:tensorflow:From c:\ProgramData\anaconda3\envs\tensorflow_env\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 9/9 [==============================] - 0s 2ms/step
# (5, 39, 14) (5, 1)
# 157/157 [==============================] - 1s 3ms/step
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 3ms/step
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 3ms/step
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 3ms/step
# 157/157 [==============================] - 1s 3ms/step
# 157/157 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 157/157 [==============================] - 0s 2ms/step
# 18/18 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 2ms/step
# 18/18 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 2ms/step
# 18/18 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 2ms/step
# 18/18 [==============================] - 0s 3ms/step
# 157/157 [==============================] - 0s 2ms/step
# 18/18 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 0s 2ms/step
# 10
# 157/157 [==============================] - 0s 2ms/step
# 10
# 157/157 [==============================] - 0s 2ms/step
# 10
# 157/157 [==============================] - 0s 2ms/step
# 10
# 157/157 [==============================] - 0s 3ms/step
# 10
# 157/157 [==============================] - 0s 2ms/step
# 10
# 157/157 [==============================] - 0s 2ms/step
# 10
# 157/157 [==============================] - 0s 2ms/step
# 10
# 157/157 [==============================] - 0s 2ms/step
# 10
# 157/157 [==============================] - 0s 3ms/step
# 10
# 157/157 [==============================] - 0s 2ms/step
# 10
# 157/157 [==============================] - 0s 2ms/step
# 10
# 157/157 [==============================] - 0s 2ms/step
# 10
# 157/157 [==============================] - 0s 2ms/step
# 10
# 157/157 [==============================] - 0s 2ms/step
# 10
# 157/157 [==============================] - 0s 2ms/step
# 10
# 157/157 [==============================] - 0s 2ms/step
# 10
# 157/157 [==============================] - 0s 3ms/step
# 10
# 157/157 [==============================] - 0s 2ms/step
# 10
# 157/157 [==============================] - 0s 2ms/step
# 10
# 157/157 [==============================] - 0s 2ms/step
# 10
# 157/157 [==============================] - 0s 2ms/step
# 10
# 157/157 [==============================] - 0s 2ms/step
# 10
# 157/157 [==============================] - 1s 6ms/step
# 10
# 157/157 [==============================] - 0s 2ms/step
# 10
# 157/157 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 157/157 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 157/157 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 157/157 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 157/157 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 157/157 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 157/157 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 157/157 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 157/157 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 157/157 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 157/157 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 157/157 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 157/157 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 157/157 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 157/157 [==============================] - 1s 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 157/157 [==============================] - 1s 5ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 157/157 [==============================] - 1s 5ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 5ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 157/157 [==============================] - 1s 4ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 23ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 27ms/step
# 8/8 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 25ms/step
# 8/8 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 8ms/step
# 18/18 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 23ms/step
# 8/8 [==============================] - 0s 9ms/step
# 18/18 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 9ms/step
# 18/18 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 23ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 25ms/step
# 8/8 [==============================] - 0s 9ms/step
# 18/18 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 23ms/step
# 8/8 [==============================] - 0s 9ms/step
# 18/18 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 23ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 23ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 23ms/step
# 8/8 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 26ms/step
# 8/8 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 23ms/step
# 8/8 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 23ms/step
# 8/8 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 23ms/step
# 8/8 [==============================] - 0s 8ms/step
# 10
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 8ms/step
# 10
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 9ms/step
# 10
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 8ms/step
# 10
# 1/1 [==============================] - 0s 23ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 9ms/step
# 10
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 9ms/step
# 10
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 24ms/step
# 8/8 [==============================] - 0s 10ms/step
# 10
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 12ms/step
# 10
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 8ms/step
# 10
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 7ms/step
# 10
# 1/1 [==============================] - 0s 23ms/step
# 8/8 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 9ms/step
# 10
# 1/1 [==============================] - 0s 23ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 23ms/step
# 8/8 [==============================] - 0s 9ms/step
# 10
# 1/1 [==============================] - 0s 24ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 23ms/step
# 8/8 [==============================] - 0s 9ms/step
# 10
# 1/1 [==============================] - 0s 23ms/step
# 8/8 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 23ms/step
# 8/8 [==============================] - 0s 9ms/step
# 10
# 1/1 [==============================] - 0s 24ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 9ms/step
# 10
# 1/1 [==============================] - 0s 24ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 23ms/step
# 8/8 [==============================] - 0s 9ms/step
# 10
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 9ms/step
# 10
# 1/1 [==============================] - 0s 23ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 25ms/step
# 8/8 [==============================] - 0s 9ms/step
# 10
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 9ms/step
# 10
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 26ms/step
# 8/8 [==============================] - 0s 9ms/step
# 10
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 23ms/step
# 8/8 [==============================] - 0s 6ms/step
# 10
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 5ms/step
# 10
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 6ms/step
# 10
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 8ms/step
# 10
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 24ms/step
# 8/8 [==============================] - 0s 14ms/step
# 10
# 1/1 [==============================] - 0s 71ms/step
# 8/8 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 35ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 29ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 223ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 32ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 24ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 172ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 155ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 23ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 339ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 88ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 47ms/step
# 8/8 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 24ms/step
# 8/8 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 23ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 41ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 28ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 67ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 29ms/step
# 8/8 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 5ms/step
# ...
# 1/1 [==============================] - 1s 585ms/step - loss: 8191.0713 - mse: 8190.3057 - val_loss: 8177.4521 - val_mse: 8176.6938
# 1/1 [==============================] - 1s 617ms/step - loss: 8053.1045 - mse: 8052.3359 - val_loss: 7822.4150 - val_mse: 7821.6523
# 1/1 [==============================] - 1s 594ms/step - loss: 8152.0039 - mse: 8151.2383 - val_loss: 8307.6650 - val_mse: 8306.9043
# 1/1 [==============================] - 1s 578ms/step - loss: 8109.2710 - mse: 8108.5010 - val_loss: 8101.7842 - val_mse: 8101.0195
# 1/1 [==============================] - 1s 632ms/step - loss: 8190.2314 - mse: 8189.4639 - val_loss: 8134.7085 - val_mse: 8133.9468
# 1/1 [==============================] - 1s 597ms/step - loss: 8101.1592 - mse: 8100.3921 - val_loss: 7750.4819 - val_mse: 7749.7202
# 1/1 [==============================] - 1s 565ms/step - loss: 8175.4087 - mse: 8174.6406 - val_loss: 8138.5220 - val_mse: 8137.7588
# 1/1 [==============================] - 1s 613ms/step - loss: 8059.5796 - mse: 8058.8110 - val_loss: 8168.9155 - val_mse: 8168.1523
# 1/1 [==============================] - 1s 600ms/step - loss: 8203.0234 - mse: 8202.2568 - val_loss: 8125.0508 - val_mse: 8124.2891
# 1/1 [==============================] - 1s 582ms/step - loss: 8073.7397 - mse: 8072.9717 - val_loss: 8008.4111 - val_mse: 8007.6484
# 1/1 [==============================] - 1s 602ms/step - loss: 8093.5518 - mse: 8092.7842 - val_loss: 8602.7061 - val_mse: 8601.9434
# 1/1 [==============================] - 1s 630ms/step - loss: 8105.7412 - mse: 8104.9741 - val_loss: 8087.5327 - val_mse: 8086.7695
# 1/1 [==============================] - 1s 598ms/step - loss: 7993.2275 - mse: 7992.4624 - val_loss: 8009.4092 - val_mse: 8008.6484
# 1/1 [==============================] - 1s 601ms/step - loss: 8125.2568 - mse: 8124.4946 - val_loss: 8189.8838 - val_mse: 8189.1260
# 1/1 [==============================] - 1s 582ms/step - loss: 8053.5679 - mse: 8052.8037 - val_loss: 8394.3496 - val_mse: 8393.5898
# 1/1 [==============================] - 1s 614ms/step - loss: 8136.8735 - mse: 8136.1064 - val_loss: 7716.4678 - val_mse: 7715.7061
# 1/1 [==============================] - 1s 581ms/step - loss: 8027.7407 - mse: 8026.9766 - val_loss: 7997.4204 - val_mse: 7996.6616
# 1/1 [==============================] - 1s 578ms/step - loss: 8092.4619 - mse: 8091.6924 - val_loss: 8106.0498 - val_mse: 8105.2852
# 1/1 [==============================] - 1s 632ms/step - loss: 8209.1455 - mse: 8208.3809 - val_loss: 8115.4204 - val_mse: 8114.6592
# 1/1 [==============================] - 1s 601ms/step - loss: 8074.4600 - mse: 8073.6924 - val_loss: 8086.1885 - val_mse: 8085.4243
# 1/1 [==============================] - 1s 595ms/step - loss: 8197.6865 - mse: 8196.9199 - val_loss: 8202.7871 - val_mse: 8202.0244
# 1/1 [==============================] - 1s 595ms/step - loss: 8025.9229 - mse: 8025.1577 - val_loss: 8182.7803 - val_mse: 8182.0195
# 1/1 [==============================] - 1s 609ms/step - loss: 8124.6279 - mse: 8123.8623 - val_loss: 8289.2705 - val_mse: 8288.5098
# 1/1 [==============================] - 1s 589ms/step - loss: 7988.8413 - mse: 7988.0732 - val_loss: 7778.1055 - val_mse: 7777.3413
# 1/1 [==============================] - 1s 582ms/step - loss: 8245.6172 - mse: 8244.8496 - val_loss: 7895.0171 - val_mse: 7894.2539
# 1/1 [==============================] - 1s 672ms/step - loss: 7993.7944 - mse: 7993.0288 - val_loss: 7886.6211 - val_mse: 7885.8594
# 1/1 [==============================] - 1s 583ms/step - loss: 8142.4463 - mse: 8141.6772 - val_loss: 7823.1416 - val_mse: 7822.3765
# 1/1 [==============================] - 1s 602ms/step - loss: 8093.9883 - mse: 8093.2202 - val_loss: 8356.0527 - val_mse: 8355.2891
# 1/1 [==============================] - 1s 599ms/step - loss: 8026.8687 - mse: 8026.1030 - val_loss: 7878.6313 - val_mse: 7877.8696
# 1/1 [==============================] - 1s 582ms/step - loss: 8107.8486 - mse: 8107.0811 - val_loss: 8525.4561 - val_mse: 8524.6924
# 1/1 [==============================] - 1s 569ms/step - loss: 8084.7944 - mse: 8084.0288 - val_loss: 8131.9360 - val_mse: 8131.1743
# 1/1 [==============================] - 1s 632ms/step - loss: 8071.3389 - mse: 8070.5732 - val_loss: 7640.8916 - val_mse: 7640.1299
# 1/1 [==============================] - 1s 597ms/step - loss: 8212.8154 - mse: 8212.0449 - val_loss: 7935.6494 - val_mse: 7934.8818
# 1/1 [==============================] - 1s 599ms/step - loss: 8124.3970 - mse: 8123.6318 - val_loss: 8205.2256 - val_mse: 8204.4639
# 1/1 [==============================] - 1s 619ms/step - loss: 8084.4873 - mse: 8083.7217 - val_loss: 7759.3813 - val_mse: 7758.6187
# 1/1 [==============================] - 1s 602ms/step - loss: 7959.8970 - mse: 7959.1304 - val_loss: 8247.4834 - val_mse: 8246.7207
# 1/1 [==============================] - 1s 670ms/step - loss: 8150.0352 - mse: 8149.2686 - val_loss: 7934.9463 - val_mse: 7934.1826
# 1/1 [==============================] - 1s 602ms/step - loss: 8145.0010 - mse: 8144.2344 - val_loss: 8063.1626 - val_mse: 8062.3999
# 1/1 [==============================] - 1s 601ms/step - loss: 8068.2373 - mse: 8067.4702 - val_loss: 8465.3486 - val_mse: 8464.5840
# 1/1 [==============================] - 1s 596ms/step - loss: 8134.8740 - mse: 8134.1094 - val_loss: 8136.3076 - val_mse: 8135.5469
# 1/1 [==============================] - 1s 609ms/step - loss: 8076.7056 - mse: 8075.9375 - val_loss: 7916.4062 - val_mse: 7915.6406
# 1/1 [==============================] - 1s 600ms/step - loss: 7966.5015 - mse: 7965.7344 - val_loss: 8088.8564 - val_mse: 8088.0913
# 1/1 [==============================] - 1s 617ms/step - loss: 7989.0791 - mse: 7988.3125 - val_loss: 8538.5537 - val_mse: 8537.7910
# 1/1 [==============================] - 1s 645ms/step - loss: 8114.9072 - mse: 8114.1396 - val_loss: 7771.8008 - val_mse: 7771.0366
# 1/1 [==============================] - 1s 651ms/step - loss: 8119.4619 - mse: 8118.6968 - val_loss: 7477.6523 - val_mse: 7476.8906
# 1/1 [==============================] - 1s 584ms/step - loss: 8181.1147 - mse: 8180.3467 - val_loss: 7940.0132 - val_mse: 7939.2476
# 1/1 [==============================] - 1s 600ms/step - loss: 8041.4883 - mse: 8040.7178 - val_loss: 7527.9131 - val_mse: 7527.1460
# 1/1 [==============================] - 1s 583ms/step - loss: 8170.8643 - mse: 8170.0977 - val_loss: 8201.8633 - val_mse: 8201.0996
# 1/1 [==============================] - 1s 601ms/step - loss: 8058.1929 - mse: 8057.4243 - val_loss: 8709.8770 - val_mse: 8709.1104
# 1/1 [==============================] - 1s 637ms/step - loss: 8027.4702 - mse: 8026.7061 - val_loss: 8515.9844 - val_mse: 8515.2227
# 1/1 [==============================] - 1s 590ms/step - loss: 8158.9336 - mse: 8158.1680 - val_loss: 8041.6826 - val_mse: 8040.9194
# 1/1 [==============================] - 1s 600ms/step - loss: 8126.3892 - mse: 8125.6235 - val_loss: 8038.5493 - val_mse: 8037.7861
# 1/1 [==============================] - 1s 632ms/step - loss: 8157.4229 - mse: 8156.6562 - val_loss: 7919.3501 - val_mse: 7918.5869
# 1/1 [==============================] - 1s 616ms/step - loss: 8054.1963 - mse: 8053.4307 - val_loss: 8712.7158 - val_mse: 8711.9521
# 1/1 [==============================] - 1s 589ms/step - loss: 8103.2197 - mse: 8102.4517 - val_loss: 8624.3301 - val_mse: 8623.5645
# 1/1 [==============================] - 1s 632ms/step - loss: 8178.0811 - mse: 8177.3140 - val_loss: 8429.0566 - val_mse: 8428.2910
# 1/1 [==============================] - 1s 600ms/step - loss: 8147.9961 - mse: 8147.2305 - val_loss: 8905.7568 - val_mse: 8904.9941
# 1/1 [==============================] - 1s 583ms/step - loss: 8116.8423 - mse: 8116.0713 - val_loss: 8084.7163 - val_mse: 8083.9478
# 1/1 [==============================] - 1s 601ms/step - loss: 8155.7842 - mse: 8155.0186 - val_loss: 7444.8062 - val_mse: 7444.0430
# 1/1 [==============================] - 1s 582ms/step - loss: 8143.0991 - mse: 8142.3345 - val_loss: 8115.1475 - val_mse: 8114.3853
# 1/1 [==============================] - 1s 582ms/step - loss: 8290.0146 - mse: 8289.2480 - val_loss: 8289.3916 - val_mse: 8288.6270
# 1/1 [==============================] - 1s 599ms/step - loss: 8240.3604 - mse: 8239.5918 - val_loss: 8301.5312 - val_mse: 8300.7656
# 1/1 [==============================] - 1s 600ms/step - loss: 8001.2646 - mse: 8000.5010 - val_loss: 7540.6416 - val_mse: 7539.8789
# 1/1 [==============================] - 1s 599ms/step - loss: 8189.9673 - mse: 8189.2007 - val_loss: 8053.5688 - val_mse: 8052.8037
# 1/1 [==============================] - 1s 578ms/step - loss: 8171.0376 - mse: 8170.2725 - val_loss: 8725.7061 - val_mse: 8724.9434
# 1/1 [==============================] - 1s 582ms/step - loss: 8036.3608 - mse: 8035.5923 - val_loss: 7590.4658 - val_mse: 7589.6992
# 1/1 [==============================] - 1s 634ms/step - loss: 8181.0952 - mse: 8180.3281 - val_loss: 7439.1143 - val_mse: 7438.3486
# 1/1 [==============================] - 1s 583ms/step - loss: 8166.8154 - mse: 8166.0483 - val_loss: 9455.4785 - val_mse: 9454.7129
# 1/1 [==============================] - 1s 583ms/step - loss: 8104.2085 - mse: 8103.4414 - val_loss: 8218.1299 - val_mse: 8217.3643
# 1/1 [==============================] - 1s 632ms/step - loss: 8103.7891 - mse: 8103.0205 - val_loss: 8707.0811 - val_mse: 8706.3145
# 1/1 [==============================] - 1s 600ms/step - loss: 8110.2080 - mse: 8109.4424 - val_loss: 8132.2007 - val_mse: 8131.4375
# 1/1 [==============================] - 1s 573ms/step - loss: 8306.2227 - mse: 8305.4561 - val_loss: 7993.0874 - val_mse: 7992.3232
# 1/1 [==============================] - 1s 599ms/step - loss: 8025.6104 - mse: 8024.8447 - val_loss: 8077.0000 - val_mse: 8076.2368
# 1/1 [==============================] - 1s 582ms/step - loss: 8060.0483 - mse: 8059.2812 - val_loss: 8362.8164 - val_mse: 8362.0508
# 1/1 [==============================] - 1s 581ms/step - loss: 8145.0454 - mse: 8144.2788 - val_loss: 7757.3022 - val_mse: 7756.5376
# 1/1 [==============================] - 1s 585ms/step - loss: 7959.5181 - mse: 7958.7524 - val_loss: 8067.7881 - val_mse: 8067.0244
# 1/1 [==============================] - 1s 633ms/step - loss: 8099.0586 - mse: 8098.2905 - val_loss: 8289.4111 - val_mse: 8288.6445
# 1/1 [==============================] - 1s 662ms/step - loss: 8008.6572 - mse: 8007.8906 - val_loss: 8395.3486 - val_mse: 8394.5840
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 82ms/step
# 18/18 [==============================] - 0s 3ms/step
# 18/18 [==============================] - 0s 3ms/step
# 18/18 [==============================] - 0s 4ms/step
# 18/18 [==============================] - 0s 3ms/step
# 18/18 [==============================] - 0s 3ms/step
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 16
# 16
# 16
# 16
# 16
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 100%|██████████| 10/10 [24:42:29<00:00, 8894.96s/it]

# %%
# (39, 0.5, 130)

# %%
results
# Out:
#         RMSE  std_RMSE       S_score  std_S_score         MSE  std_MSE  \
# 0  15.800766       0.0   2086.453300          0.0  249.664200      0.0
# 1  16.447907       0.0   4022.611415          0.0  270.533600      0.0
# 2  16.419840       0.0   4819.084388          0.0  269.611115      0.0
# 3  20.123318       0.0  13132.789443          0.0  404.947937      0.0
# 4  15.306671       0.0   2865.203385          0.0  234.294159      0.0
# 5  13.877312       0.0   1013.694073          0.0  192.579788      0.0
# 6  17.544110       0.0   7182.533595          0.0  307.795807      0.0
# 7  13.793738       0.0    856.677975          0.0  190.267181      0.0
# 8  15.903536       0.0   2568.799504          0.0  252.922485      0.0
# 9  13.283127       0.0    776.637507          0.0  176.441467      0.0
#
#    dropout activation  batch_size
# 0      0.2       tanh         128
# 1      0.2       tanh         128
# 2      0.2       tanh         128
# 3      0.2       tanh         128
# 4      0.2       tanh         128
# 5      0.2       tanh         128
# 6      0.2       tanh         128
# 7      0.2       tanh         128
# 8      0.2       tanh         128
# 9      0.2       tanh         128
