# %%
from __future__ import print_function
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import matplotlib.pyplot as plt

from lime.lime_tabular import RecurrentTabularExplainer
from tqdm import tqdm
import keras
from sp_modif.model_function import *
from sp_modif.methods import *
from sp_modif.data_prep import *
from sp_modif.evaluator import *
from sp_modif.SHAP import *
from sp_modif.L2X import *

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import random
# import keras
import math

from sklearn.metrics import mean_squared_error, r2_score 
from sklearn.model_selection import GroupKFold
from sklearn import preprocessing
from keras import backend as K
from sklearn.preprocessing import MinMaxScaler , StandardScaler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Activation, GRU
from scipy import optimize
from methods import *
from tensorflow.keras import optimizers
# %matplotlib inline
# Out:
# WARNING:tensorflow:From c:\ProgramData\anaconda3\envs\tensorflow_env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
SEED = 0
def set_seed(seed=SEED):
    os.environ['PYTHONHASHSEED'] = str(SEED)
    random.seed(SEED)
    np.random.seed(SEED)
    tf.random.set_seed(SEED)

# Appeler la fonction pour fixer le seed
set_seed(SEED)

# %%
# Function to generate explanations
# Function explanation for lime

def get_lime_explanation(data, e, L2X=False) :
    # e  = fn = model.predict
    # Iniatialisation
    df_expplanation = pd.DataFrame(columns=[str(i) for i in range(data.shape[1]*data.shape[2])])

    # Get explanations
    for row in range(data.shape[0]) : 
        explanation = lime_explainer.explain_instance(data[row],
                                                      e,
                                                      num_features=data.shape[1]*data.shape[2]) 
        # fn = model.predict, initialize lime_explainer = Reccurent()
        lime_values = explanation.local_exp[1]
        # Add explanation in df_explanation
        lime_dict = {}
        for tup in lime_values :
            lime_dict[str(tup[0])] = tup[1]
        df_expplanation.loc[len(df_expplanation)] = lime_dict
    
    return df_expplanation

# # Function explanation for others
def get_explainations(data, e, L2X = False) :
    
    # df diemnsion
    if L2X==True :
        X_to_def_col = data[0:1]
        explanation_test = e.explain(X_to_def_col.reshape((X_to_def_col.shape[0], -1)))
        num_columns = explanation_test.flatten().shape[0]
        
    else : 
        explanation_test = e.explain(data[0:1])
        num_columns = explanation_test.flatten().shape[0]
    
    # Iniatialisation
    df_expplanation = pd.DataFrame(columns=[str(i) for i in range(num_columns)])

    # Get explanations
    for row in range(data.shape[0]) :
        if L2X==True:
            X_row = data[row:row+1]
            explanation = e.explain(X_row.reshape((X_row.shape[0], -1)))
        else :
            explanation = e.explain(data[row:row+1])
        # Add explanation in df_explanation
        explanation = explanation.flatten()
        feature_dict = {}
        for i in range(num_columns) :
            feature_dict[str(i)] = explanation[i]
        df_expplanation.loc[len(df_expplanation)] = feature_dict
    
    return df_expplanation

# %% [markdown]
# ### FD001

# %%
# Load data and preprocess
train, test, y_test = prepare_data('FD001.txt')
print(train.shape, test.shape, y_test.shape)
sensor_names = ['T20','T24','T30','T50','P20','P15','P30','Nf','Nc','epr','Ps30','phi',
                'NRf','NRc','BPR','farB','htBleed','Nf_dmd','PCNfR_dmd','W31','W32']

remaining_sensors = ['T24','T30','T50','P30','Nf','Nc','Ps30','phi',
                'NRf','NRc','BPR','htBleed','W31','W32'] # selection based on main_notebook

drop_sensors = [element for element in sensor_names if element not in remaining_sensors]
# Out:
# (20631, 27) (13096, 26) (100, 1)

# %%
def model001(input_shape, weights_file):
    '''
    node = 256, activation = tanh, dropout = 0.3, bs = 64
    '''
     
    nodes_per_layer = 256
    activation_value= 'tanh'
    dropout = 0.3
    bs = 64

    cb = keras.callbacks.EarlyStopping(monitor='loss', patience=4)
    model = Sequential()
    model.add(LSTM(nodes_per_layer, activation=activation_value, input_shape=input_shape))
    model.add(Dropout(dropout))
    model.add(Dense(1))
    model.compile(loss='mse',
                  optimizer=Adam(learning_rate=0.001))
    model.save_weights(weights_file)

    return model

# %%
# from tqdm import tqdm
# sequence_lengths = [30, 35, 38, 39, 40]
# list_alpha = [0.2, 0.3, 0.5]
# list_upper = [120,125,130]
# metrics_names = ['identity', 'separability', 'stability', 'coherence', 'completness', 'congruence',
#                  'selectivity', 'accumen',	'Verm_stability',	'fidelity',	'sparsity', 'instability']
                     
# df_metrics = pd.DataFrame()
# results = pd.DataFrame()
# # all_list = [(seq, alpha, upper) for seq in sequence_lengths for alpha in list_alpha for rec_rul in list_upper]
# all_list = []
# for sq in sequence_lengths:
#     for alpha in list_alpha:
#         for upper in list_upper:
#             triplet = (sq, alpha, upper)
#             all_list.append(triplet)
# list_d = []
# list_df_metric = []
# df_metrics = pd.DataFrame()
# results = pd.DataFrame()

# for elm in tqdm(all_list[7:10]):
#     # Modeling
#     print(elm)
#     print('...')
#     sequence_length = elm[0]
#     alpha = elm[1]
#     upper = elm[2]
    
#     learning_rate_ = 0.001
#     dropout = 0.3
#     activation = 'tanh'
#     epochs = 20
#     batch_size = 64
#     train = rul_piecewise_fct(train, upper)

#     #Model creation
#     weights_file = "fd001_result/" + str(alpha) + '1lstm_hyper_parameter_weights.h5'
#     input_shape = (sequence_length, len(remaining_sensors))
#     model = model001(input_shape, weights_file)
    
#     # Data prepration
#     X_train_interim, X_test_interim = prep_data(train, test, drop_sensors, remaining_sensors, alpha)

#     # create sequences train, test
#     train_array = gen_data_wrapper(X_train_interim, sequence_length,remaining_sensors)
#     label_array = gen_label_wrapper(X_train_interim, sequence_length, ['RUL'])

#     test_gen = (list(gen_test_data(X_test_interim[X_test_interim['Unit']==unit_nr], sequence_length,remaining_sensors, -99.))
#                for unit_nr in X_test_interim['Unit'].unique())
    
#     test_array = np.concatenate(list(test_gen)).astype(np.float32)
#     test_rul = rul_piecewise_fct(y_test,upper)
#     print(train_array.shape, label_array.shape, test_array.shape)
    
#     mse_val = []
#     R2_val = []
#     RMSE = []
#     score_val = []
#     mse = []
#     # Model fitting
#     with tf.device('/device:GPU:0'):
#         history = model.fit(train_array, label_array,
#                                 validation_data=(test_array, test_rul),
#                                 epochs=epochs,
#                                 batch_size=batch_size,
#                                 # callbacks=[cb],
#                                 verbose=0)
#         mse.append(history.history['val_loss'][-1])

#         y_hat_val_split = model.predict(test_array)
#         R2_val.append(r2_score(test_rul, y_hat_val_split))
#         RMSE.append(np.sqrt(mean_squared_error(test_rul, y_hat_val_split)))
#         score_val.append(compute_s_score(test_rul, y_hat_val_split))
            
        
#     #  append results
#     d = {'RMSE' :np.mean(RMSE), 'std_RMSE' :np.std(RMSE),
#          'S_score' :np.mean(score_val), 'std_S_score' :np.std(score_val),
#          'MSE':np.mean(mse), 'std_MSE':np.std(mse),
#         #  'nodes':str(nodes_per_layer),
#          'dropout':dropout, 
#          'activation':activation, 'batch_size':batch_size}

# #     results = results.append(pd.DataFrame(d, index=[0]), ignore_index=True)
#     results = pd.concat([results, pd.DataFrame(d, index=[0])], ignore_index=True)
#     results.to_csv('fd001_result/performance_by_layerlbis7_10.csv')
     
        
#     # Get explanation and calculate the score
    
#     with tf.device('/device:GPU:0'):  
#         for rd in range(5):
        
#                 # Get explanation and calculate the score
#                 # Echantillonage
#                 n_individus = test_array.shape[0]

#                 # # Choisir aléatoirement 5 indices d'individus
#                 np.random.seed(rd)
#                 indices_choisis = np.random.choice(n_individus, size=5, replace=False)

#                 # Sélectionner les données correspondant aux indices choisis
#                 test_array_sampling = test_array[indices_choisis, :, :]
#                 label_array_sampling = y_test.values[indices_choisis, :]

#                 # Afficher les dimensions des données sélectionnées
#                 print(test_array_sampling.shape, label_array_sampling.shape)
                
#                 # distance matrix XX'
#                 X_dist = pd.DataFrame(squareform(pdist(test_array_sampling.reshape((test_array_sampling.shape[0], -1)))))

#                 # LIME
#                 lime_explainer = RecurrentTabularExplainer(test_array, training_labels=label_array,
#                                                                 feature_names=remaining_sensors,
#                                                                 mode = 'regression',
#                                                                 )
#                 lime_values = get_lime_explanation(test_array_sampling, e = model.predict)
#                 lime_values.shape
#                 Lime_dist = pd.DataFrame(squareform(pdist(lime_values))) # Lime values explanation matrix

#                 #Lime's metrics
#                 list_metrics_lime = {}
#                 list_metrics_lime['identity'] = identity(X_dist, Lime_dist)
#                 list_metrics_lime['separability'] = separability(X_dist, Lime_dist)
#                 list_metrics_lime['stability'] = stability(X_dist, Lime_dist)
#                 list_metrics_lime['coherence'], list_metrics_lime['completness'], list_metrics_lime['congruence'] = coherence(model=model.predict, 
#                                                                 explainer = get_lime_explanation,
#                                                             samples=test_array_sampling,
#                                                                 targets=label_array, e = model.predict)
#                 list_metrics_lime['selectivity'] = selectivity(model=model.predict, explainer = get_lime_explanation,
#                                                             samples=test_array_sampling, e_x = model.predict)
#                 list_metrics_lime['accumen'] = acumen(get_lime_explanation, test_array_sampling, e=model.predict)
#                 list_metrics_lime['Verm_stability'] = stability_Velmurugan(get_lime_explanation, test_array_sampling,
#                                                                             e=model.predict, top_features=200)
#                 list_metrics_lime['fidelity'], list_metrics_lime['sparsity'] = fidelity(model=model.predict, 
#                                                                 explainer = get_lime_explanation,
#                                                                 samples=test_array_sampling,
#                                                                 e = model.predict, L2X=True)
#                 list_metrics_lime['instability'] = instability(model=model.predict, 
#                                                                 explainer = get_lime_explanation,
#                                                                 samples=test_array_sampling,
#                                                                 e = model.predict, L2X=True)
                
#                 list_metrics_lime['alpha'] = alpha
#                 list_metrics_lime['upper'] = upper
#                 list_metrics_lime['sequence_length'] = sequence_length
#                 list_metrics_lime['explainer'] = 'lime'
#                 # list_metrics_lime['model'] = model_name

#                 df_metrics = pd.concat([df_metrics, pd.DataFrame([list_metrics_lime])])

#                 # SHAP
#                 e = KernelSHAP(model)
#                 shapvalues = get_explainations(test_array_sampling, e)
#                 shapvalues.shape

#                 list_metrics_shap = {}
#                 shap_dist = pd.DataFrame(squareform(pdist(shapvalues))) # shap values explanation matrix

#                 list_metrics_shap['identity'] = identity(X_dist, shap_dist)
#                 list_metrics_shap['separability'] = separability(X_dist, shap_dist)
#                 list_metrics_shap['stability'] = stability(X_dist, shap_dist)
#                 list_metrics_shap['coherence'], list_metrics_shap['completness'], list_metrics_shap['congruence'] = coherence(model=model.predict, 
#                                                                 explainer = get_explainations,
#                                                             samples=test_array_sampling,
#                                                                 targets=label_array, e = e)
#                 list_metrics_shap['selectivity'] = selectivity(model=model.predict, explainer = get_explainations,
#                                                 samples=test_array_sampling, e_x=e)
#                 list_metrics_shap['accumen'] = acumen(get_explainations, test_array_sampling, e=e)
#                 list_metrics_shap['Verm_stability'] = stability_Velmurugan(get_explainations, test_array_sampling,
#                                                                             e=e, top_features=200)
#                 list_metrics_shap['fidelity'], list_metrics_shap['sparsity']= fidelity(model=model.predict, 
#                                                                 explainer = get_explainations,
#                                                                 samples=test_array_sampling,
#                                                                 e = e)
#                 list_metrics_shap['instability']= instability(model=model.predict, 
#                                                                 explainer = get_explainations,
#                                                                 samples=test_array_sampling,
#                                                                 e = e)
                
#                 list_metrics_shap['alpha'] = alpha
#                 list_metrics_shap['upper'] = upper
#                 list_metrics_shap['sequence_length'] = sequence_length
#                 list_metrics_shap['explainer'] = 'shap'
#                 # list_metrics_shap['model'] = model_name

#                 df_metrics = pd.concat([df_metrics, pd.DataFrame([list_metrics_shap])])
                
#                 # L2X
#                 e = L2X(model.predict, test_array_sampling)
#                 l2xvalues = get_explainations(test_array_sampling, e, L2X=True)
#                 l2xvalues.shape

#                 # L2X's metrics
#                 list_metrics_l2x = {}
#                 l2x_dist = pd.DataFrame(squareform(pdist(l2xvalues))) # Lime values explanation matrix

#                 list_metrics_l2x['identity'] = identity(X_dist, l2x_dist)
#                 list_metrics_l2x['separability'] = separability(X_dist, l2x_dist)
#                 list_metrics_l2x['stability'] = stability(X_dist, l2x_dist)
#                 list_metrics_l2x['coherence'], list_metrics_l2x['completness'], list_metrics_l2x['congruence'] = coherence(model=model.predict, explainer = get_explainations,
#                                                             samples=test_array_sampling, targets=label_array_sampling, e = e, L2X=True)
#                 list_metrics_l2x['selectivity'] = selectivity(model=model.predict, explainer = get_explainations,
#                                                 samples=test_array_sampling, e_x=e, L2X=True)
#                 list_metrics_l2x['accumen'] = acumen(get_explainations, test_array_sampling, e=e, L2X=True)
#                 list_metrics_l2x['Verm_stability'] = stability_Velmurugan(get_explainations, test_array_sampling,
#                                                                             e=e, top_features=200, L2X=True)
#                 list_metrics_l2x['fidelity'], list_metrics_l2x['sparsity']= fidelity(model=model.predict, 
#                                                                 explainer = get_explainations,
#                                                                 samples=test_array_sampling,
#                                                                 e = e, L2X=True)
#                 list_metrics_l2x['instability'] = instability(model=model.predict, 
#                                                                 explainer = get_explainations,
#                                                                 samples=test_array_sampling,
#                                                                 e = e, L2X=True)
                
#                 list_metrics_l2x['alpha'] = alpha
#                 list_metrics_l2x['upper'] = upper
#                 list_metrics_l2x['sequence_length'] = sequence_length
#                 list_metrics_l2x['explainer'] = 'l2x'
#                 # list_metrics_l2x['model'] = model_name


#                 df_metrics = pd.concat([df_metrics, pd.DataFrame([list_metrics_l2x])])
#     df_metrics.to_csv('fd001_result/quality_by_layerlbis7_10.csv')

# %%
from tqdm import tqdm
sequence_lengths = [30, 35, 38, 39, 40]
list_alpha = [0.2, 0.3, 0.5]
list_upper = [120,125,130]
metrics_names = ['identity', 'separability', 'stability', 'coherence', 'completness', 'congruence',
                 'selectivity', 'accumen',	'Verm_stability',	'fidelity',	'sparsity', 'instability']
                     
df_metrics = pd.DataFrame()
results = pd.DataFrame()
# all_list = [(seq, alpha, upper) for seq in sequence_lengths for alpha in list_alpha for rec_rul in list_upper]
all_list = []
for sq in sequence_lengths:
    for alpha in list_alpha:
        for upper in list_upper:
            triplet = (sq, alpha, upper)
            all_list.append(triplet)
list_d = []
list_df_metric = []
df_metrics = pd.DataFrame()
results = pd.DataFrame()

for elm in tqdm(all_list[12:13]):
    # Modeling
    print(elm)
    print('...')
    sequence_length = elm[0]
    alpha = elm[1]
    upper = elm[2]
    
    learning_rate_ = 0.001
    dropout = 0.3
    activation = 'tanh'
    epochs = 20
    batch_size = 64
    train = rul_piecewise_fct(train, upper)

    #Model creation
    weights_file = "fd001_result/" + str(alpha) + '1lstm_hyper_parameter_weights.h5'
    input_shape = (sequence_length, len(remaining_sensors))
    model = model001(input_shape, weights_file)
    
    # Data prepration
    X_train_interim, X_test_interim = prep_data(train, test, drop_sensors, remaining_sensors, alpha)

    # create sequences train, test
    train_array = gen_data_wrapper(X_train_interim, sequence_length,remaining_sensors)
    label_array = gen_label_wrapper(X_train_interim, sequence_length, ['RUL'])

    test_gen = (list(gen_test_data(X_test_interim[X_test_interim['Unit']==unit_nr], sequence_length,remaining_sensors, -99.))
               for unit_nr in X_test_interim['Unit'].unique())
    
    test_array = np.concatenate(list(test_gen)).astype(np.float32)
    test_rul = rul_piecewise_fct(y_test,upper)
    print(train_array.shape, label_array.shape, test_array.shape)
    
    mse_val = []
    R2_val = []
    RMSE = []
    score_val = []
    mse = []
    # Model fitting
    with tf.device('/device:GPU:0'):
        history = model.fit(train_array, label_array,
                                validation_data=(test_array, test_rul),
                                epochs=epochs,
                                batch_size=batch_size,
                                # callbacks=[cb],
                                verbose=1)
        mse.append(history.history['val_loss'][-1])

        y_hat_val_split = model.predict(test_array)
        R2_val.append(r2_score(test_rul, y_hat_val_split))
        RMSE.append(np.sqrt(mean_squared_error(test_rul, y_hat_val_split)))
        score_val.append(compute_s_score(test_rul, y_hat_val_split))
            
        
    #  append results
    d = {'RMSE' :np.mean(RMSE), 'std_RMSE' :np.std(RMSE),
         'S_score' :np.mean(score_val), 'std_S_score' :np.std(score_val),
         'MSE':np.mean(mse), 'std_MSE':np.std(mse),
        #  'nodes':str(nodes_per_layer),
         'dropout':dropout, 
         'activation':activation, 'batch_size':batch_size}

#     results = results.append(pd.DataFrame(d, index=[0]), ignore_index=True)
    results = pd.concat([results, pd.DataFrame(d, index=[0])], ignore_index=True)
    results.to_csv('fd001_result/performance_by_layerl1213aj.csv')
     
        
    # Get explanation and calculate the score
    
    with tf.device('/device:GPU:0'):  
        for rd in range(5):
        
                # Get explanation and calculate the scores
                # Echantillonage
                n_individus = test_array.shape[0]

                # # Choisir aléatoirement 5 indices d'individus
                np.random.seed(rd)
                indices_choisis = np.random.choice(n_individus, size=5, replace=False)

                # Sélectionner les données correspondant aux indices choisis
                test_array_sampling = test_array[indices_choisis, :, :]
                label_array_sampling = y_test.values[indices_choisis, :]

                # Afficher les dimensions des données sélectionnées
                print(test_array_sampling.shape, label_array_sampling.shape)
                
                # distance matrix XX'
                X_dist = pd.DataFrame(squareform(pdist(test_array_sampling.reshape((test_array_sampling.shape[0], -1)))))

                # LIME
                lime_explainer = RecurrentTabularExplainer(test_array, training_labels=label_array,
                                                                feature_names=remaining_sensors,
                                                                mode = 'regression',
                                                                )
                lime_values = get_lime_explanation(test_array_sampling, e = model.predict)
                lime_values.shape
                Lime_dist = pd.DataFrame(squareform(pdist(lime_values))) # Lime values explanation matrix

                #Lime's metrics
                list_metrics_lime = {}
                list_metrics_lime['identity'] = identity(X_dist, Lime_dist)
                list_metrics_lime['separability'] = separability(X_dist, Lime_dist)
                list_metrics_lime['stability'] = stability(X_dist, Lime_dist)
                list_metrics_lime['coherence'], list_metrics_lime['completness'], list_metrics_lime['congruence'] = coherence(model=model.predict, 
                                                                explainer = get_lime_explanation,
                                                            samples=test_array_sampling,
                                                                targets=label_array, e = model.predict)
                list_metrics_lime['selectivity'] = selectivity(model=model.predict, explainer = get_lime_explanation,
                                                            samples=test_array_sampling, e_x = model.predict)
                list_metrics_lime['accumen'] = acumen(get_lime_explanation, test_array_sampling, e=model.predict)
                list_metrics_lime['Verm_stability'] = stability_Velmurugan(get_lime_explanation, test_array_sampling,
                                                                            e=model.predict, top_features=200)
                list_metrics_lime['fidelity'], list_metrics_lime['sparsity'] = fidelity(model=model.predict, 
                                                                explainer = get_lime_explanation,
                                                                samples=test_array_sampling,
                                                                e = model.predict, L2X=True)
                list_metrics_lime['instability'] = instability(model=model.predict, 
                                                                explainer = get_lime_explanation,
                                                                samples=test_array_sampling,
                                                                e = model.predict, L2X=True)
                
                list_metrics_lime['alpha'] = alpha
                list_metrics_lime['upper'] = upper
                list_metrics_lime['sequence_length'] = sequence_length
                list_metrics_lime['explainer'] = 'lime'
                # list_metrics_lime['model'] = model_name

                df_metrics = pd.concat([df_metrics, pd.DataFrame([list_metrics_lime])])

                # SHAP
                e = KernelSHAP(model)
                shapvalues = get_explainations(test_array_sampling, e)
                shapvalues.shape

                list_metrics_shap = {}
                shap_dist = pd.DataFrame(squareform(pdist(shapvalues))) # shap values explanation matrix

                list_metrics_shap['identity'] = identity(X_dist, shap_dist)
                list_metrics_shap['separability'] = separability(X_dist, shap_dist)
                list_metrics_shap['stability'] = stability(X_dist, shap_dist)
                list_metrics_shap['coherence'], list_metrics_shap['completness'], list_metrics_shap['congruence'] = coherence(model=model.predict, 
                                                                explainer = get_explainations,
                                                            samples=test_array_sampling,
                                                                targets=label_array, e = e)
                list_metrics_shap['selectivity'] = selectivity(model=model.predict, explainer = get_explainations,
                                                samples=test_array_sampling, e_x=e)
                list_metrics_shap['accumen'] = acumen(get_explainations, test_array_sampling, e=e)
                list_metrics_shap['Verm_stability'] = stability_Velmurugan(get_explainations, test_array_sampling,
                                                                            e=e, top_features=200)
                list_metrics_shap['fidelity'], list_metrics_shap['sparsity']= fidelity(model=model.predict, 
                                                                explainer = get_explainations,
                                                                samples=test_array_sampling,
                                                                e = e)
                list_metrics_shap['instability']= instability(model=model.predict, 
                                                                explainer = get_explainations,
                                                                samples=test_array_sampling,
                                                                e = e)
                
                list_metrics_shap['alpha'] = alpha
                list_metrics_shap['upper'] = upper
                list_metrics_shap['sequence_length'] = sequence_length
                list_metrics_shap['explainer'] = 'shap'
                # list_metrics_shap['model'] = model_name

                df_metrics = pd.concat([df_metrics, pd.DataFrame([list_metrics_shap])])
                
                # L2X
                e = L2X(model.predict, test_array_sampling)
                l2xvalues = get_explainations(test_array_sampling, e, L2X=True)
                l2xvalues.shape

                # L2X's metrics
                list_metrics_l2x = {}
                l2x_dist = pd.DataFrame(squareform(pdist(l2xvalues))) # Lime values explanation matrix

                list_metrics_l2x['identity'] = identity(X_dist, l2x_dist)
                list_metrics_l2x['separability'] = separability(X_dist, l2x_dist)
                list_metrics_l2x['stability'] = stability(X_dist, l2x_dist)
                list_metrics_l2x['coherence'], list_metrics_l2x['completness'], list_metrics_l2x['congruence'] = coherence(model=model.predict, explainer = get_explainations,
                                                            samples=test_array_sampling, targets=label_array_sampling, e = e, L2X=True)
                list_metrics_l2x['selectivity'] = selectivity(model=model.predict, explainer = get_explainations,
                                                samples=test_array_sampling, e_x=e, L2X=True)
                list_metrics_l2x['accumen'] = acumen(get_explainations, test_array_sampling, e=e, L2X=True)
                list_metrics_l2x['Verm_stability'] = stability_Velmurugan(get_explainations, test_array_sampling,
                                                                            e=e, top_features=200, L2X=True)
                list_metrics_l2x['fidelity'], list_metrics_l2x['sparsity']= fidelity(model=model.predict, 
                                                                explainer = get_explainations,
                                                                samples=test_array_sampling,
                                                                e = e, L2X=True)
                list_metrics_l2x['instability'] = instability(model=model.predict, 
                                                                explainer = get_explainations,
                                                                samples=test_array_sampling,
                                                                e = e, L2X=True)
                
                list_metrics_l2x['alpha'] = alpha
                list_metrics_l2x['upper'] = upper
                list_metrics_l2x['sequence_length'] = sequence_length
                list_metrics_l2x['explainer'] = 'l2x'
                # list_metrics_l2x['model'] = model_name


                df_metrics = pd.concat([df_metrics, pd.DataFrame([list_metrics_l2x])])
    df_metrics.to_csv('fd001_result/quality_by_layerl1213aj.csv')
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# (35, 0.3, 120)
# ...
# (17231, 35, 14) (17231, 1) (100, 35, 14)
# Epoch 1/20
# 270/270 [==============================] - 10s 33ms/step - loss: 2962.8528 - val_loss: 1600.6893
# Epoch 2/20
# 270/270 [==============================] - 8s 30ms/step - loss: 1650.2091 - val_loss: 1557.4868
# Epoch 3/20
# 270/270 [==============================] - 8s 31ms/step - loss: 1625.8734 - val_loss: 1559.9343
# Epoch 4/20
# 270/270 [==============================] - 8s 30ms/step - loss: 1617.9941 - val_loss: 1546.9312
# Epoch 5/20
# 270/270 [==============================] - 9s 32ms/step - loss: 1597.4117 - val_loss: 1513.8367
# Epoch 6/20
# 270/270 [==============================] - 8s 31ms/step - loss: 1511.5740 - val_loss: 1302.3258
# Epoch 7/20
# 270/270 [==============================] - 9s 33ms/step - loss: 671.4527 - val_loss: 457.5509
# Epoch 8/20
# 270/270 [==============================] - 9s 32ms/step - loss: 371.5744 - val_loss: 229.2596
# Epoch 9/20
# 270/270 [==============================] - 9s 32ms/step - loss: 213.4577 - val_loss: 354.7657
# Epoch 10/20
# 270/270 [==============================] - 9s 32ms/step - loss: 179.4958 - val_loss: 333.4643
# Epoch 11/20
# 270/270 [==============================] - 8s 31ms/step - loss: 168.4233 - val_loss: 372.2513
# Epoch 12/20
# 270/270 [==============================] - 9s 33ms/step - loss: 162.3270 - val_loss: 358.6430
# Epoch 13/20
# 270/270 [==============================] - 9s 33ms/step - loss: 159.1888 - val_loss: 488.5155
# Epoch 14/20
# 270/270 [==============================] - 9s 32ms/step - loss: 157.5890 - val_loss: 374.3196
# Epoch 15/20
# 270/270 [==============================] - 9s 33ms/step - loss: 157.6306 - val_loss: 379.6151
# Epoch 16/20
# 270/270 [==============================] - 8s 31ms/step - loss: 157.3182 - val_loss: 481.6504
# Epoch 17/20
# 270/270 [==============================] - 9s 33ms/step - loss: 150.8178 - val_loss: 478.0657
# Epoch 18/20
# 270/270 [==============================] - 9s 33ms/step - loss: 150.6979 - val_loss: 390.0262
# Epoch 19/20
# 270/270 [==============================] - 9s 32ms/step - loss: 150.0959 - val_loss: 384.6925
# Epoch 20/20
# 270/270 [==============================] - 9s 33ms/step - loss: 146.8763 - val_loss: 373.2808
# 4/4 [==============================] - 0s 20ms/step
# (5, 35, 14) (5, 1)
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 12ms/step
# 157/157 [==============================] - 2s 13ms/step
# 157/157 [==============================] - 2s 12ms/step
# 157/157 [==============================] - 1s 9ms/step
# 157/157 [==============================] - 1s 7ms/step
# 157/157 [==============================] - 1s 8ms/step
# 157/157 [==============================] - 3s 17ms/step
# 157/157 [==============================] - 2s 12ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 13ms/step
# 157/157 [==============================] - 1s 9ms/step
# 16/16 [==============================] - 0s 12ms/step
# 157/157 [==============================] - 2s 10ms/step
# 16/16 [==============================] - 0s 8ms/step
# 157/157 [==============================] - 2s 11ms/step
# 16/16 [==============================] - 0s 10ms/step
# 157/157 [==============================] - 2s 12ms/step
# 16/16 [==============================] - 0s 9ms/step
# 157/157 [==============================] - 2s 13ms/step
# 16/16 [==============================] - 0s 13ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 13ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 1s 7ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 1s 8ms/step
# 157/157 [==============================] - 2s 12ms/step
# 157/157 [==============================] - 1s 9ms/step
# 157/157 [==============================] - 1s 9ms/step
# 157/157 [==============================] - 2s 12ms/step
# 10
# 157/157 [==============================] - 2s 13ms/step
# 10
# 157/157 [==============================] - 2s 12ms/step
# 10
# 157/157 [==============================] - 1s 8ms/step
# 10
# 157/157 [==============================] - 2s 12ms/step
# 10
# 157/157 [==============================] - 2s 12ms/step
# 10
# 157/157 [==============================] - 2s 10ms/step
# 10
# 157/157 [==============================] - 2s 11ms/step
# 10
# 157/157 [==============================] - 2s 13ms/step
# 10
# 157/157 [==============================] - 1s 8ms/step
# 10
# 157/157 [==============================] - 1s 9ms/step
# 10
# 157/157 [==============================] - 2s 13ms/step
# 10
# 157/157 [==============================] - 2s 11ms/step
# 10
# 157/157 [==============================] - 1s 9ms/step
# 10
# 157/157 [==============================] - 2s 11ms/step
# 10
# 157/157 [==============================] - 2s 11ms/step
# 10
# 157/157 [==============================] - 2s 10ms/step
# 10
# 157/157 [==============================] - 2s 10ms/step
# 10
# 157/157 [==============================] - 1s 8ms/step
# 10
# 157/157 [==============================] - 2s 10ms/step
# 10
# 157/157 [==============================] - 2s 14ms/step
# 10
# 157/157 [==============================] - 2s 12ms/step
# 10
# 157/157 [==============================] - 2s 13ms/step
# 10
# 157/157 [==============================] - 2s 10ms/step
# 10
# 157/157 [==============================] - 2s 11ms/step
# 10
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 157/157 [==============================] - 2s 12ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 157/157 [==============================] - 2s 13ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 10ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 157/157 [==============================] - 2s 12ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 13ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 157/157 [==============================] - 1s 7ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 13ms/step
# 157/157 [==============================] - 1s 7ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 2ms/step
# 157/157 [==============================] - 1s 9ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 157/157 [==============================] - 1s 8ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 12ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 157/157 [==============================] - 1s 9ms/step
# 1/1 [==============================] - 0s 804us/step
# 1/1 [==============================] - 0s 14ms/step
# 157/157 [==============================] - 1s 8ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 3ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 157/157 [==============================] - 1s 8ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 157/157 [==============================] - 1s 7ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 7ms/step
# 157/157 [==============================] - 1s 9ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 157/157 [==============================] - 2s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 157/157 [==============================] - 1s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 17ms/step
# 157/157 [==============================] - 1s 8ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 0s/step
# 157/157 [==============================] - 1s 8ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 157/157 [==============================] - 1s 8ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 10ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 0s/step
# 157/157 [==============================] - 2s 14ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 21ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 157/157 [==============================] - 1s 8ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 157/157 [==============================] - 2s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 157/157 [==============================] - 1s 8ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 22ms/step
# 157/157 [==============================] - 2s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 12ms/step
# 157/157 [==============================] - 1s 8ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 26ms/step
# 157/157 [==============================] - 2s 15ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 14ms/step
# 157/157 [==============================] - 2s 9ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 18ms/step
# 157/157 [==============================] - 2s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 3ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 157/157 [==============================] - 2s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 157/157 [==============================] - 2s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 157/157 [==============================] - 1s 8ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 1s 8ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 1s 9ms/step
# 157/157 [==============================] - 2s 12ms/step
# 157/157 [==============================] - 1s 7ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 13ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 1s 8ms/step
# 157/157 [==============================] - 1s 9ms/step
# 157/157 [==============================] - 2s 12ms/step
# 157/157 [==============================] - 2s 13ms/step
# 157/157 [==============================] - 1s 9ms/step
# 157/157 [==============================] - 1s 7ms/step
# 157/157 [==============================] - 1s 7ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 1s 9ms/step
# 157/157 [==============================] - 2s 13ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 1s 9ms/step
# 157/157 [==============================] - 1s 8ms/step
# 157/157 [==============================] - 2s 14ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 1s 9ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 1s 9ms/step
# 157/157 [==============================] - 2s 12ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 1s 8ms/step
# 157/157 [==============================] - 1s 9ms/step
# 157/157 [==============================] - 3s 18ms/step
# 157/157 [==============================] - 1s 9ms/step
# 157/157 [==============================] - 2s 12ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 1s 10ms/step
# 157/157 [==============================] - 1s 9ms/step
# 157/157 [==============================] - 1s 9ms/step
# 157/157 [==============================] - 1s 8ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 6ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 7ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 0s/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 4ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 14ms/step
# 16/16 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 17ms/step
# 16/16 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 9ms/step
# 8/8 [==============================] - 0s 17ms/step
# 16/16 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 0s/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 17ms/step
# 16/16 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 6ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 19ms/step
# 16/16 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 12ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 11ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 7ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 10ms/step
# 8/8 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 10ms/step
# 8/8 [==============================] - 0s 19ms/step
# 10
# 1/1 [==============================] - 0s 40ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 22ms/step
# 10
# 1/1 [==============================] - 0s 12ms/step
# 8/8 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 8/8 [==============================] - 0s 15ms/step
# 10
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 15ms/step
# 10
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 0s/step
# 8/8 [==============================] - 0s 15ms/step
# 10
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 19ms/step
# 12
# 1/1 [==============================] - 0s 10ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 15ms/step
# 12
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 19ms/step
# 12
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 0s/step
# 8/8 [==============================] - 0s 18ms/step
# 12
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 9ms/step
# 8/8 [==============================] - 0s 15ms/step
# 12
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 10
# 1/1 [==============================] - 0s 11ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 14ms/step
# 10
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 19ms/step
# 10
# 1/1 [==============================] - 0s 180us/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 17ms/step
# 10
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 19ms/step
# 10
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 17ms/step
# 10
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 15ms/step
# 10
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 18ms/step
# 10
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 10
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 16ms/step
# 10
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 5ms/step
# 8/8 [==============================] - 0s 18ms/step
# 10
# 1/1 [==============================] - 0s 6ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 8/8 [==============================] - 0s 20ms/step
# 10
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 8/8 [==============================] - 0s 11ms/step
# 10
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 18ms/step
# 10
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 17ms/step
# 10
# 1/1 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 13ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 5ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 12ms/step
# 8/8 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 12ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 27ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 10ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 11ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 8/8 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 619us/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 0s/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 9ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 24ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 34ms/step
# 8/8 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 10ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 4ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 0s/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 7ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 5ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 0s/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 36ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 33ms/step
# 8/8 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 36ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 0s/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 13ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 1ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 0s/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 0s/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 2ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 0s/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 28ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 1ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 10ms/step
# 8/8 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 0s/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 0s/step
# 8/8 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 0s/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 0s/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 3ms/step
# 8/8 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 813us/step
# ...
# 1/1 [==============================] - 1s 681ms/step - loss: 5792.8667 - mse: 5792.1143 - val_loss: 5716.6973 - val_mse: 5715.9497
# 1/1 [==============================] - 1s 643ms/step - loss: 5681.9258 - mse: 5681.1743 - val_loss: 5665.5117 - val_mse: 5664.7651
# 1/1 [==============================] - 1s 716ms/step - loss: 5670.5591 - mse: 5669.8086 - val_loss: 5722.3604 - val_mse: 5721.6147
# 1/1 [==============================] - 1s 659ms/step - loss: 5710.2441 - mse: 5709.4932 - val_loss: 5821.7222 - val_mse: 5820.9756
# 1/1 [==============================] - 1s 620ms/step - loss: 5754.3643 - mse: 5753.6123 - val_loss: 5676.9937 - val_mse: 5676.2456
# 1/1 [==============================] - 1s 650ms/step - loss: 5742.4819 - mse: 5741.7314 - val_loss: 5707.9961 - val_mse: 5707.2495
# 1/1 [==============================] - 1s 600ms/step - loss: 5625.8911 - mse: 5625.1372 - val_loss: 5690.6899 - val_mse: 5689.9404
# 1/1 [==============================] - 1s 603ms/step - loss: 5739.7070 - mse: 5738.9561 - val_loss: 5717.5605 - val_mse: 5716.8135
# 1/1 [==============================] - 1s 620ms/step - loss: 5743.6167 - mse: 5742.8628 - val_loss: 5605.5049 - val_mse: 5604.7549
# 1/1 [==============================] - 1s 639ms/step - loss: 5765.7202 - mse: 5764.9678 - val_loss: 5719.0659 - val_mse: 5718.3174
# 1/1 [==============================] - 1s 616ms/step - loss: 5725.6436 - mse: 5724.8940 - val_loss: 5702.4595 - val_mse: 5701.7139
# 1/1 [==============================] - 1s 679ms/step - loss: 5724.8071 - mse: 5724.0581 - val_loss: 5700.1895 - val_mse: 5699.4443
# 1/1 [==============================] - 1s 643ms/step - loss: 5658.0874 - mse: 5657.3350 - val_loss: 5663.8799 - val_mse: 5663.1313
# 1/1 [==============================] - 1s 637ms/step - loss: 5700.1904 - mse: 5699.4370 - val_loss: 5695.3481 - val_mse: 5694.5981
# 1/1 [==============================] - 1s 645ms/step - loss: 5704.0835 - mse: 5703.3301 - val_loss: 5710.7915 - val_mse: 5710.0415
# 1/1 [==============================] - 4s 4s/step - loss: 5690.8164 - mse: 5690.0659 - val_loss: 5725.7168 - val_mse: 5724.9697
# 1/1 [==============================] - 1s 592ms/step - loss: 5796.6250 - mse: 5795.8701 - val_loss: 5772.8584 - val_mse: 5772.1069
# 1/1 [==============================] - 1s 614ms/step - loss: 5738.7314 - mse: 5737.9824 - val_loss: 5741.6270 - val_mse: 5740.8809
# 1/1 [==============================] - 1s 639ms/step - loss: 5754.9121 - mse: 5754.1587 - val_loss: 5717.6372 - val_mse: 5716.8862
# 1/1 [==============================] - 1s 654ms/step - loss: 5727.5132 - mse: 5726.7622 - val_loss: 5719.1025 - val_mse: 5718.3545
# 1/1 [==============================] - 1s 602ms/step - loss: 5735.4038 - mse: 5734.6533 - val_loss: 5795.1064 - val_mse: 5794.3584
# 1/1 [==============================] - 1s 603ms/step - loss: 5725.3950 - mse: 5724.6440 - val_loss: 5766.3374 - val_mse: 5765.5889
# 1/1 [==============================] - 1s 609ms/step - loss: 5735.0835 - mse: 5734.3315 - val_loss: 5716.9790 - val_mse: 5716.2295
# 1/1 [==============================] - 1s 662ms/step - loss: 5692.6807 - mse: 5691.9297 - val_loss: 5625.7007 - val_mse: 5624.9526
# 1/1 [==============================] - 1s 859ms/step - loss: 5576.1870 - mse: 5575.4321 - val_loss: 5680.8687 - val_mse: 5680.1167
# 1/1 [==============================] - 1s 763ms/step - loss: 5689.6670 - mse: 5688.9150 - val_loss: 5705.7524 - val_mse: 5705.0034
# 1/1 [==============================] - 1s 682ms/step - loss: 5746.0757 - mse: 5745.3188 - val_loss: 5661.1787 - val_mse: 5660.4248
# 1/1 [==============================] - 1s 646ms/step - loss: 5731.7891 - mse: 5731.0352 - val_loss: 5728.8916 - val_mse: 5728.1406
# 1/1 [==============================] - 1s 692ms/step - loss: 5669.2520 - mse: 5668.5000 - val_loss: 5781.4980 - val_mse: 5780.7485
# 1/1 [==============================] - 1s 628ms/step - loss: 5747.1152 - mse: 5746.3638 - val_loss: 5791.4204 - val_mse: 5790.6714
# 1/1 [==============================] - 1s 612ms/step - loss: 5678.7808 - mse: 5678.0298 - val_loss: 5819.5923 - val_mse: 5818.8438
# 1/1 [==============================] - 1s 628ms/step - loss: 5764.1348 - mse: 5763.3838 - val_loss: 5685.1475 - val_mse: 5684.3989
# 1/1 [==============================] - 1s 621ms/step - loss: 5695.5991 - mse: 5694.8477 - val_loss: 5703.3340 - val_mse: 5702.5850
# 1/1 [==============================] - 1s 617ms/step - loss: 5709.1836 - mse: 5708.4302 - val_loss: 5749.3623 - val_mse: 5748.6108
# 1/1 [==============================] - 1s 631ms/step - loss: 5738.2812 - mse: 5737.5293 - val_loss: 5733.8882 - val_mse: 5733.1382
# 1/1 [==============================] - 1s 619ms/step - loss: 5689.7759 - mse: 5689.0234 - val_loss: 5707.5659 - val_mse: 5706.8154
# 1/1 [==============================] - 1s 628ms/step - loss: 5748.2231 - mse: 5747.4692 - val_loss: 5740.5195 - val_mse: 5739.7676
# 1/1 [==============================] - 1s 695ms/step - loss: 5680.1465 - mse: 5679.3955 - val_loss: 5806.3652 - val_mse: 5805.6162
# 1/1 [==============================] - 1s 623ms/step - loss: 5773.8618 - mse: 5773.1099 - val_loss: 5725.1626 - val_mse: 5724.4126
# 1/1 [==============================] - 1s 610ms/step - loss: 5807.2598 - mse: 5806.5063 - val_loss: 5650.0142 - val_mse: 5649.2632
# 1/1 [==============================] - 1s 621ms/step - loss: 5730.0796 - mse: 5729.3276 - val_loss: 5699.8682 - val_mse: 5699.1177
# 1/1 [==============================] - 1s 624ms/step - loss: 5648.0239 - mse: 5647.2729 - val_loss: 5713.3140 - val_mse: 5712.5649
# 1/1 [==============================] - 1s 626ms/step - loss: 5816.5747 - mse: 5815.8213 - val_loss: 5620.4575 - val_mse: 5619.7061
# 1/1 [==============================] - 1s 619ms/step - loss: 5705.3242 - mse: 5704.5693 - val_loss: 5757.8945 - val_mse: 5757.1411
# 1/1 [==============================] - 1s 624ms/step - loss: 5769.7720 - mse: 5769.0186 - val_loss: 5722.0781 - val_mse: 5721.3267
# 1/1 [==============================] - 1s 682ms/step - loss: 5650.8184 - mse: 5650.0649 - val_loss: 5585.1899 - val_mse: 5584.4385
# 1/1 [==============================] - 1s 757ms/step - loss: 5673.3848 - mse: 5672.6333 - val_loss: 5689.4053 - val_mse: 5688.6558
# 1/1 [==============================] - 1s 599ms/step - loss: 5749.6899 - mse: 5748.9385 - val_loss: 5619.2739 - val_mse: 5618.5239
# 1/1 [==============================] - 1s 610ms/step - loss: 5634.0444 - mse: 5633.2925 - val_loss: 5726.9995 - val_mse: 5726.2485
# 1/1 [==============================] - 1s 601ms/step - loss: 5692.7202 - mse: 5691.9683 - val_loss: 5781.4902 - val_mse: 5780.7397
# 1/1 [==============================] - 1s 668ms/step - loss: 5624.2354 - mse: 5623.4834 - val_loss: 5681.0366 - val_mse: 5680.2861
# 1/1 [==============================] - 1s 611ms/step - loss: 5656.5488 - mse: 5655.7954 - val_loss: 5677.6284 - val_mse: 5676.8760
# 1/1 [==============================] - 1s 668ms/step - loss: 5752.5947 - mse: 5751.8457 - val_loss: 5650.6436 - val_mse: 5649.8955
# 1/1 [==============================] - 1s 615ms/step - loss: 5770.2373 - mse: 5769.4844 - val_loss: 5691.6538 - val_mse: 5690.9023
# 1/1 [==============================] - 1s 638ms/step - loss: 5761.4736 - mse: 5760.7207 - val_loss: 5832.5679 - val_mse: 5831.8159
# 1/1 [==============================] - 1s 675ms/step - loss: 5768.3921 - mse: 5767.6392 - val_loss: 5618.4722 - val_mse: 5617.7207
# 1/1 [==============================] - 1s 716ms/step - loss: 5700.4990 - mse: 5699.7490 - val_loss: 5769.7783 - val_mse: 5769.0298
# 1/1 [==============================] - 1s 711ms/step - loss: 5746.3706 - mse: 5745.6196 - val_loss: 5633.6953 - val_mse: 5632.9458
# 1/1 [==============================] - 1s 699ms/step - loss: 5675.4614 - mse: 5674.7095 - val_loss: 5741.5781 - val_mse: 5740.8271
# 1/1 [==============================] - 1s 622ms/step - loss: 5771.3159 - mse: 5770.5630 - val_loss: 5797.6260 - val_mse: 5796.8740
# 1/1 [==============================] - 1s 685ms/step - loss: 5826.7881 - mse: 5826.0361 - val_loss: 5751.8623 - val_mse: 5751.1113
# 1/1 [==============================] - 1s 637ms/step - loss: 5792.4048 - mse: 5791.6514 - val_loss: 5715.7510 - val_mse: 5714.9985
# 1/1 [==============================] - 1s 655ms/step - loss: 5716.8262 - mse: 5716.0732 - val_loss: 5616.2261 - val_mse: 5615.4746
# 1/1 [==============================] - 1s 669ms/step - loss: 5853.9956 - mse: 5853.2437 - val_loss: 5815.0874 - val_mse: 5814.3364
# 1/1 [==============================] - 1s 716ms/step - loss: 5757.9595 - mse: 5757.2080 - val_loss: 5840.3979 - val_mse: 5839.6475
# 1/1 [==============================] - 1s 622ms/step - loss: 5755.7847 - mse: 5755.0327 - val_loss: 5720.4443 - val_mse: 5719.6934
# 1/1 [==============================] - 1s 652ms/step - loss: 5728.4482 - mse: 5727.6938 - val_loss: 5595.8604 - val_mse: 5595.1069
# 1/1 [==============================] - 1s 604ms/step - loss: 5721.4165 - mse: 5720.6631 - val_loss: 5738.2944 - val_mse: 5737.5415
# 1/1 [==============================] - 1s 666ms/step - loss: 5663.7163 - mse: 5662.9678 - val_loss: 5667.0195 - val_mse: 5666.2715
# 1/1 [==============================] - 1s 684ms/step - loss: 5727.5078 - mse: 5726.7534 - val_loss: 5849.5562 - val_mse: 5848.8032
# 1/1 [==============================] - 1s 647ms/step - loss: 5666.6143 - mse: 5665.8604 - val_loss: 5667.2534 - val_mse: 5666.5005
# 1/1 [==============================] - 1s 644ms/step - loss: 5716.1050 - mse: 5715.3525 - val_loss: 5716.2505 - val_mse: 5715.4990
# 1/1 [==============================] - 1s 663ms/step - loss: 5679.4707 - mse: 5678.7163 - val_loss: 5655.3970 - val_mse: 5654.6436
# 1/1 [==============================] - 1s 634ms/step - loss: 5790.5757 - mse: 5789.8232 - val_loss: 5718.5947 - val_mse: 5717.8428
# 1/1 [==============================] - 1s 672ms/step - loss: 5730.2769 - mse: 5729.5225 - val_loss: 5840.0933 - val_mse: 5839.3398
# 1/1 [==============================] - 1s 681ms/step - loss: 5728.9961 - mse: 5728.2466 - val_loss: 5768.4624 - val_mse: 5767.7134
# 1/1 [==============================] - 1s 693ms/step - loss: 5736.0059 - mse: 5735.2524 - val_loss: 5751.6538 - val_mse: 5750.9014
# 1/1 [==============================] - 1s 676ms/step - loss: 5740.2314 - mse: 5739.4805 - val_loss: 5813.5928 - val_mse: 5812.8428
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 34ms/step
# 16/16 [==============================] - 0s 10ms/step
# 16/16 [==============================] - 0s 10ms/step
# 16/16 [==============================] - 0s 9ms/step
# 16/16 [==============================] - 0s 8ms/step
# 16/16 [==============================] - 0s 10ms/step
# 19
# 19
# 19
# 19
# 19
# 10
# 10
# 10
# 10
# 10
# 24
# 24
# 24
# 24
# 24
# 10
# 10
# 10
# 10
# 10
# 12
# 12
# 12
# 12
# 12
# 1/1 [==============================] - 0s 247us/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 12ms/step
# 100%|██████████| 1/1 [2:37:19<00:00, 9439.65s/it]

# %%
# (40, 0.5, 125)
