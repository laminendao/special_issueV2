# %%
from __future__ import print_function
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import matplotlib.pyplot as plt

from lime.lime_tabular import RecurrentTabularExplainer
from tqdm import tqdm
import keras
from sp_modif.model_function import *
from sp_modif.methods import *
from sp_modif.data_prep import *
from sp_modif.evaluator import *
from sp_modif.SHAP import *
from sp_modif.L2X import *

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import random
# import keras
import math

from sklearn.metrics import mean_squared_error, r2_score 
from sklearn.model_selection import GroupKFold
from sklearn import preprocessing
from keras import backend as K
from sklearn.preprocessing import MinMaxScaler , StandardScaler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Activation, GRU
from scipy import optimize
from methods import *
from tensorflow.keras import optimizers
# %matplotlib inline
# Out:
# WARNING:tensorflow:From c:\ProgramData\anaconda3\envs\tensorflow_env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
SEED = 0
def set_seed(seed=SEED):
    os.environ['PYTHONHASHSEED'] = str(SEED)
    random.seed(SEED)
    np.random.seed(SEED)
    tf.random.set_seed(SEED)

# Appeler la fonction pour fixer le seed
set_seed(SEED)

# %%
# Function to generate explanations
# Function explanation for lime

def get_lime_explanation(data, e, L2X=False) :
    # e  = fn = model.predict
    # Iniatialisation
    df_expplanation = pd.DataFrame(columns=[str(i) for i in range(data.shape[1]*data.shape[2])])

    # Get explanations
    for row in range(data.shape[0]) : 
        explanation = lime_explainer.explain_instance(data[row],
                                                      e,
                                                      num_features=data.shape[1]*data.shape[2]) 
        # fn = model.predict, initialize lime_explainer = Reccurent()
        lime_values = explanation.local_exp[1]
        # Add explanation in df_explanation
        lime_dict = {}
        for tup in lime_values :
            lime_dict[str(tup[0])] = tup[1]
        df_expplanation.loc[len(df_expplanation)] = lime_dict
    
    return df_expplanation

# # Function explanation for others
def get_explainations(data, e, L2X = False) :
    
    # df diemnsion
    if L2X==True :
        X_to_def_col = data[0:1]
        explanation_test = e.explain(X_to_def_col.reshape((X_to_def_col.shape[0], -1)))
        num_columns = explanation_test.flatten().shape[0]
        
    else : 
        explanation_test = e.explain(data[0:1])
        num_columns = explanation_test.flatten().shape[0]
    
    # Iniatialisation
    df_expplanation = pd.DataFrame(columns=[str(i) for i in range(num_columns)])

    # Get explanations
    for row in range(data.shape[0]) :
        if L2X==True:
            X_row = data[row:row+1]
            explanation = e.explain(X_row.reshape((X_row.shape[0], -1)))
        else :
            explanation = e.explain(data[row:row+1])
        # Add explanation in df_explanation
        explanation = explanation.flatten()
        feature_dict = {}
        for i in range(num_columns) :
            feature_dict[str(i)] = explanation[i]
        df_expplanation.loc[len(df_expplanation)] = feature_dict
    
    return df_expplanation

# %% [markdown]
# ### FD001

# %%
# Load data and preprocess
train, test, y_test = prepare_data('FD001.txt')
print(train.shape, test.shape, y_test.shape)
sensor_names = ['T20','T24','T30','T50','P20','P15','P30','Nf','Nc','epr','Ps30','phi',
                'NRf','NRc','BPR','farB','htBleed','Nf_dmd','PCNfR_dmd','W31','W32']

remaining_sensors = ['T24','T30','T50','P30','Nf','Nc','Ps30','phi',
                'NRf','NRc','BPR','htBleed','W31','W32'] # selection based on main_notebook

drop_sensors = [element for element in sensor_names if element not in remaining_sensors]
# Out:
# (20631, 27) (13096, 26) (100, 1)

# %%
def model001(input_shape, weights_file):
    '''
    node = 256, activation = tanh, dropout = 0.3, bs = 64
    '''
     
    nodes_per_layer = 256
    activation_value= 'tanh'
    dropout = 0.3
    bs = 64

    cb = keras.callbacks.EarlyStopping(monitor='loss', patience=4)
    model = Sequential()
    model.add(LSTM(nodes_per_layer, activation=activation_value, input_shape=input_shape))
    model.add(Dropout(dropout))
    model.add(Dense(1))
    model.compile(loss='mse',
                  optimizer=Adam(learning_rate=0.001))
    model.save_weights(weights_file)

    return model

# %%
# from tqdm import tqdm
# sequence_lengths = [30, 35, 38, 39, 40]
# list_alpha = [0.2, 0.3, 0.5]
# list_upper = [120,125,130]
# metrics_names = ['identity', 'separability', 'stability', 'coherence', 'completness', 'congruence',
#                  'selectivity', 'accumen',	'Verm_stability',	'fidelity',	'sparsity', 'instability']
                     
# df_metrics = pd.DataFrame()
# results = pd.DataFrame()
# # all_list = [(seq, alpha, upper) for seq in sequence_lengths for alpha in list_alpha for rec_rul in list_upper]
# all_list = []
# for sq in sequence_lengths:
#     for alpha in list_alpha:
#         for upper in list_upper:
#             triplet = (sq, alpha, upper)
#             all_list.append(triplet)
# list_d = []
# list_df_metric = []
# df_metrics = pd.DataFrame()
# results = pd.DataFrame()

# for elm in tqdm(all_list[7:10]):
#     # Modeling
#     print(elm)
#     print('...')
#     sequence_length = elm[0]
#     alpha = elm[1]
#     upper = elm[2]
    
#     learning_rate_ = 0.001
#     dropout = 0.3
#     activation = 'tanh'
#     epochs = 20
#     batch_size = 64
#     train = rul_piecewise_fct(train, upper)

#     #Model creation
#     weights_file = "fd001_result/" + str(alpha) + '1lstm_hyper_parameter_weights.h5'
#     input_shape = (sequence_length, len(remaining_sensors))
#     model = model001(input_shape, weights_file)
    
#     # Data prepration
#     X_train_interim, X_test_interim = prep_data(train, test, drop_sensors, remaining_sensors, alpha)

#     # create sequences train, test
#     train_array = gen_data_wrapper(X_train_interim, sequence_length,remaining_sensors)
#     label_array = gen_label_wrapper(X_train_interim, sequence_length, ['RUL'])

#     test_gen = (list(gen_test_data(X_test_interim[X_test_interim['Unit']==unit_nr], sequence_length,remaining_sensors, -99.))
#                for unit_nr in X_test_interim['Unit'].unique())
    
#     test_array = np.concatenate(list(test_gen)).astype(np.float32)
#     test_rul = rul_piecewise_fct(y_test,upper)
#     print(train_array.shape, label_array.shape, test_array.shape)
    
#     mse_val = []
#     R2_val = []
#     RMSE = []
#     score_val = []
#     mse = []
#     # Model fitting
#     with tf.device('/device:GPU:0'):
#         history = model.fit(train_array, label_array,
#                                 validation_data=(test_array, test_rul),
#                                 epochs=epochs,
#                                 batch_size=batch_size,
#                                 # callbacks=[cb],
#                                 verbose=0)
#         mse.append(history.history['val_loss'][-1])

#         y_hat_val_split = model.predict(test_array)
#         R2_val.append(r2_score(test_rul, y_hat_val_split))
#         RMSE.append(np.sqrt(mean_squared_error(test_rul, y_hat_val_split)))
#         score_val.append(compute_s_score(test_rul, y_hat_val_split))
            
        
#     #  append results
#     d = {'RMSE' :np.mean(RMSE), 'std_RMSE' :np.std(RMSE),
#          'S_score' :np.mean(score_val), 'std_S_score' :np.std(score_val),
#          'MSE':np.mean(mse), 'std_MSE':np.std(mse),
#         #  'nodes':str(nodes_per_layer),
#          'dropout':dropout, 
#          'activation':activation, 'batch_size':batch_size}

# #     results = results.append(pd.DataFrame(d, index=[0]), ignore_index=True)
#     results = pd.concat([results, pd.DataFrame(d, index=[0])], ignore_index=True)
#     results.to_csv('fd001_result/performance_by_layerlbis7_10.csv')
     
        
#     # Get explanation and calculate the score
    
#     with tf.device('/device:GPU:0'):  
#         for rd in range(5):
        
#                 # Get explanation and calculate the score
#                 # Echantillonage
#                 n_individus = test_array.shape[0]

#                 # # Choisir aléatoirement 5 indices d'individus
#                 np.random.seed(rd)
#                 indices_choisis = np.random.choice(n_individus, size=5, replace=False)

#                 # Sélectionner les données correspondant aux indices choisis
#                 test_array_sampling = test_array[indices_choisis, :, :]
#                 label_array_sampling = y_test.values[indices_choisis, :]

#                 # Afficher les dimensions des données sélectionnées
#                 print(test_array_sampling.shape, label_array_sampling.shape)
                
#                 # distance matrix XX'
#                 X_dist = pd.DataFrame(squareform(pdist(test_array_sampling.reshape((test_array_sampling.shape[0], -1)))))

#                 # LIME
#                 lime_explainer = RecurrentTabularExplainer(test_array, training_labels=label_array,
#                                                                 feature_names=remaining_sensors,
#                                                                 mode = 'regression',
#                                                                 )
#                 lime_values = get_lime_explanation(test_array_sampling, e = model.predict)
#                 lime_values.shape
#                 Lime_dist = pd.DataFrame(squareform(pdist(lime_values))) # Lime values explanation matrix

#                 #Lime's metrics
#                 list_metrics_lime = {}
#                 list_metrics_lime['identity'] = identity(X_dist, Lime_dist)
#                 list_metrics_lime['separability'] = separability(X_dist, Lime_dist)
#                 list_metrics_lime['stability'] = stability(X_dist, Lime_dist)
#                 list_metrics_lime['coherence'], list_metrics_lime['completness'], list_metrics_lime['congruence'] = coherence(model=model.predict, 
#                                                                 explainer = get_lime_explanation,
#                                                             samples=test_array_sampling,
#                                                                 targets=label_array, e = model.predict)
#                 list_metrics_lime['selectivity'] = selectivity(model=model.predict, explainer = get_lime_explanation,
#                                                             samples=test_array_sampling, e_x = model.predict)
#                 list_metrics_lime['accumen'] = acumen(get_lime_explanation, test_array_sampling, e=model.predict)
#                 list_metrics_lime['Verm_stability'] = stability_Velmurugan(get_lime_explanation, test_array_sampling,
#                                                                             e=model.predict, top_features=200)
#                 list_metrics_lime['fidelity'], list_metrics_lime['sparsity'] = fidelity(model=model.predict, 
#                                                                 explainer = get_lime_explanation,
#                                                                 samples=test_array_sampling,
#                                                                 e = model.predict, L2X=True)
#                 list_metrics_lime['instability'] = instability(model=model.predict, 
#                                                                 explainer = get_lime_explanation,
#                                                                 samples=test_array_sampling,
#                                                                 e = model.predict, L2X=True)
                
#                 list_metrics_lime['alpha'] = alpha
#                 list_metrics_lime['upper'] = upper
#                 list_metrics_lime['sequence_length'] = sequence_length
#                 list_metrics_lime['explainer'] = 'lime'
#                 # list_metrics_lime['model'] = model_name

#                 df_metrics = pd.concat([df_metrics, pd.DataFrame([list_metrics_lime])])

#                 # SHAP
#                 e = KernelSHAP(model)
#                 shapvalues = get_explainations(test_array_sampling, e)
#                 shapvalues.shape

#                 list_metrics_shap = {}
#                 shap_dist = pd.DataFrame(squareform(pdist(shapvalues))) # shap values explanation matrix

#                 list_metrics_shap['identity'] = identity(X_dist, shap_dist)
#                 list_metrics_shap['separability'] = separability(X_dist, shap_dist)
#                 list_metrics_shap['stability'] = stability(X_dist, shap_dist)
#                 list_metrics_shap['coherence'], list_metrics_shap['completness'], list_metrics_shap['congruence'] = coherence(model=model.predict, 
#                                                                 explainer = get_explainations,
#                                                             samples=test_array_sampling,
#                                                                 targets=label_array, e = e)
#                 list_metrics_shap['selectivity'] = selectivity(model=model.predict, explainer = get_explainations,
#                                                 samples=test_array_sampling, e_x=e)
#                 list_metrics_shap['accumen'] = acumen(get_explainations, test_array_sampling, e=e)
#                 list_metrics_shap['Verm_stability'] = stability_Velmurugan(get_explainations, test_array_sampling,
#                                                                             e=e, top_features=200)
#                 list_metrics_shap['fidelity'], list_metrics_shap['sparsity']= fidelity(model=model.predict, 
#                                                                 explainer = get_explainations,
#                                                                 samples=test_array_sampling,
#                                                                 e = e)
#                 list_metrics_shap['instability']= instability(model=model.predict, 
#                                                                 explainer = get_explainations,
#                                                                 samples=test_array_sampling,
#                                                                 e = e)
                
#                 list_metrics_shap['alpha'] = alpha
#                 list_metrics_shap['upper'] = upper
#                 list_metrics_shap['sequence_length'] = sequence_length
#                 list_metrics_shap['explainer'] = 'shap'
#                 # list_metrics_shap['model'] = model_name

#                 df_metrics = pd.concat([df_metrics, pd.DataFrame([list_metrics_shap])])
                
#                 # L2X
#                 e = L2X(model.predict, test_array_sampling)
#                 l2xvalues = get_explainations(test_array_sampling, e, L2X=True)
#                 l2xvalues.shape

#                 # L2X's metrics
#                 list_metrics_l2x = {}
#                 l2x_dist = pd.DataFrame(squareform(pdist(l2xvalues))) # Lime values explanation matrix

#                 list_metrics_l2x['identity'] = identity(X_dist, l2x_dist)
#                 list_metrics_l2x['separability'] = separability(X_dist, l2x_dist)
#                 list_metrics_l2x['stability'] = stability(X_dist, l2x_dist)
#                 list_metrics_l2x['coherence'], list_metrics_l2x['completness'], list_metrics_l2x['congruence'] = coherence(model=model.predict, explainer = get_explainations,
#                                                             samples=test_array_sampling, targets=label_array_sampling, e = e, L2X=True)
#                 list_metrics_l2x['selectivity'] = selectivity(model=model.predict, explainer = get_explainations,
#                                                 samples=test_array_sampling, e_x=e, L2X=True)
#                 list_metrics_l2x['accumen'] = acumen(get_explainations, test_array_sampling, e=e, L2X=True)
#                 list_metrics_l2x['Verm_stability'] = stability_Velmurugan(get_explainations, test_array_sampling,
#                                                                             e=e, top_features=200, L2X=True)
#                 list_metrics_l2x['fidelity'], list_metrics_l2x['sparsity']= fidelity(model=model.predict, 
#                                                                 explainer = get_explainations,
#                                                                 samples=test_array_sampling,
#                                                                 e = e, L2X=True)
#                 list_metrics_l2x['instability'] = instability(model=model.predict, 
#                                                                 explainer = get_explainations,
#                                                                 samples=test_array_sampling,
#                                                                 e = e, L2X=True)
                
#                 list_metrics_l2x['alpha'] = alpha
#                 list_metrics_l2x['upper'] = upper
#                 list_metrics_l2x['sequence_length'] = sequence_length
#                 list_metrics_l2x['explainer'] = 'l2x'
#                 # list_metrics_l2x['model'] = model_name


#                 df_metrics = pd.concat([df_metrics, pd.DataFrame([list_metrics_l2x])])
#     df_metrics.to_csv('fd001_result/quality_by_layerlbis7_10.csv')

# %%
from tqdm import tqdm
sequence_lengths = [30, 35, 38, 39, 40]
list_alpha = [0.2, 0.3, 0.5]
list_upper = [120,125,130]
metrics_names = ['identity', 'separability', 'stability', 'coherence', 'completness', 'congruence',
                 'selectivity', 'accumen',	'Verm_stability',	'fidelity',	'sparsity', 'instability']
                     
df_metrics = pd.DataFrame()
results = pd.DataFrame()
# all_list = [(seq, alpha, upper) for seq in sequence_lengths for alpha in list_alpha for rec_rul in list_upper]
all_list = []
for sq in sequence_lengths:
    for alpha in list_alpha:
        for upper in list_upper:
            triplet = (sq, alpha, upper)
            all_list.append(triplet)
list_d = []
list_df_metric = []
df_metrics = pd.DataFrame()
results = pd.DataFrame()

for elm in tqdm(all_list[43:]):
    # Modeling
    print(elm)
    print('...')
    sequence_length = elm[0]
    alpha = elm[1]
    upper = elm[2]
    
    learning_rate_ = 0.001
    dropout = 0.3
    activation = 'tanh'
    epochs = 20
    batch_size = 64
    train = rul_piecewise_fct(train, upper)

    #Model creation
    weights_file = "fd001_result/" + str(alpha) + '1lstm_hyper_parameter_weights.h5'
    input_shape = (sequence_length, len(remaining_sensors))
    model = model001(input_shape, weights_file)
    
    # Data prepration
    X_train_interim, X_test_interim = prep_data(train, test, drop_sensors, remaining_sensors, alpha)

    # create sequences train, test
    train_array = gen_data_wrapper(X_train_interim, sequence_length,remaining_sensors)
    label_array = gen_label_wrapper(X_train_interim, sequence_length, ['RUL'])

    test_gen = (list(gen_test_data(X_test_interim[X_test_interim['Unit']==unit_nr], sequence_length,remaining_sensors, -99.))
               for unit_nr in X_test_interim['Unit'].unique())
    
    test_array = np.concatenate(list(test_gen)).astype(np.float32)
    test_rul = rul_piecewise_fct(y_test,upper)
    print(train_array.shape, label_array.shape, test_array.shape)
    
    mse_val = []
    R2_val = []
    RMSE = []
    score_val = []
    mse = []
    # Model fitting
    with tf.device('/device:GPU:0'):
        history = model.fit(train_array, label_array,
                                validation_data=(test_array, test_rul),
                                epochs=epochs,
                                batch_size=batch_size,
                                # callbacks=[cb],
                                verbose=0)
        mse.append(history.history['val_loss'][-1])

        y_hat_val_split = model.predict(test_array)
        R2_val.append(r2_score(test_rul, y_hat_val_split))
        RMSE.append(np.sqrt(mean_squared_error(test_rul, y_hat_val_split)))
        score_val.append(compute_s_score(test_rul, y_hat_val_split))
            
        
    #  append results
    d = {'RMSE' :np.mean(RMSE), 'std_RMSE' :np.std(RMSE),
         'S_score' :np.mean(score_val), 'std_S_score' :np.std(score_val),
         'MSE':np.mean(mse), 'std_MSE':np.std(mse),
        #  'nodes':str(nodes_per_layer),
         'dropout':dropout, 
         'activation':activation, 'batch_size':batch_size}

#     results = results.append(pd.DataFrame(d, index=[0]), ignore_index=True)
    results = pd.concat([results, pd.DataFrame(d, index=[0])], ignore_index=True)
    results.to_csv('fd001_result/performance_by_layerl43.csv')
     
        
    # Get explanation and calculate the score
    
    with tf.device('/device:GPU:0'):  
        for rd in range(5):
        
                # Get explanation and calculate the score
                # Echantillonage
                n_individus = test_array.shape[0]

                # # Choisir aléatoirement 5 indices d'individus
                np.random.seed(rd)
                indices_choisis = np.random.choice(n_individus, size=5, replace=False)

                # Sélectionner les données correspondant aux indices choisis
                test_array_sampling = test_array[indices_choisis, :, :]
                label_array_sampling = y_test.values[indices_choisis, :]

                # Afficher les dimensions des données sélectionnées
                print(test_array_sampling.shape, label_array_sampling.shape)
                
                # distance matrix XX'
                X_dist = pd.DataFrame(squareform(pdist(test_array_sampling.reshape((test_array_sampling.shape[0], -1)))))

                # LIME
                lime_explainer = RecurrentTabularExplainer(test_array, training_labels=label_array,
                                                                feature_names=remaining_sensors,
                                                                mode = 'regression',
                                                                )
                lime_values = get_lime_explanation(test_array_sampling, e = model.predict)
                lime_values.shape
                Lime_dist = pd.DataFrame(squareform(pdist(lime_values))) # Lime values explanation matrix

                #Lime's metrics
                list_metrics_lime = {}
                list_metrics_lime['identity'] = identity(X_dist, Lime_dist)
                list_metrics_lime['separability'] = separability(X_dist, Lime_dist)
                list_metrics_lime['stability'] = stability(X_dist, Lime_dist)
                list_metrics_lime['coherence'], list_metrics_lime['completness'], list_metrics_lime['congruence'] = coherence(model=model.predict, 
                                                                explainer = get_lime_explanation,
                                                            samples=test_array_sampling,
                                                                targets=label_array, e = model.predict)
                list_metrics_lime['selectivity'] = selectivity(model=model.predict, explainer = get_lime_explanation,
                                                            samples=test_array_sampling, e_x = model.predict)
                list_metrics_lime['accumen'] = acumen(get_lime_explanation, test_array_sampling, e=model.predict)
                list_metrics_lime['Verm_stability'] = stability_Velmurugan(get_lime_explanation, test_array_sampling,
                                                                            e=model.predict, top_features=200)
                list_metrics_lime['fidelity'], list_metrics_lime['sparsity'] = fidelity(model=model.predict, 
                                                                explainer = get_lime_explanation,
                                                                samples=test_array_sampling,
                                                                e = model.predict, L2X=True)
                list_metrics_lime['instability'] = instability(model=model.predict, 
                                                                explainer = get_lime_explanation,
                                                                samples=test_array_sampling,
                                                                e = model.predict, L2X=True)
                
                list_metrics_lime['alpha'] = alpha
                list_metrics_lime['upper'] = upper
                list_metrics_lime['sequence_length'] = sequence_length
                list_metrics_lime['explainer'] = 'lime'
                # list_metrics_lime['model'] = model_name

                df_metrics = pd.concat([df_metrics, pd.DataFrame([list_metrics_lime])])

                # SHAP
                e = KernelSHAP(model)
                shapvalues = get_explainations(test_array_sampling, e)
                shapvalues.shape

                list_metrics_shap = {}
                shap_dist = pd.DataFrame(squareform(pdist(shapvalues))) # shap values explanation matrix

                list_metrics_shap['identity'] = identity(X_dist, shap_dist)
                list_metrics_shap['separability'] = separability(X_dist, shap_dist)
                list_metrics_shap['stability'] = stability(X_dist, shap_dist)
                list_metrics_shap['coherence'], list_metrics_shap['completness'], list_metrics_shap['congruence'] = coherence(model=model.predict, 
                                                                explainer = get_explainations,
                                                            samples=test_array_sampling,
                                                                targets=label_array, e = e)
                list_metrics_shap['selectivity'] = selectivity(model=model.predict, explainer = get_explainations,
                                                samples=test_array_sampling, e_x=e)
                list_metrics_shap['accumen'] = acumen(get_explainations, test_array_sampling, e=e)
                list_metrics_shap['Verm_stability'] = stability_Velmurugan(get_explainations, test_array_sampling,
                                                                            e=e, top_features=200)
                list_metrics_shap['fidelity'], list_metrics_shap['sparsity']= fidelity(model=model.predict, 
                                                                explainer = get_explainations,
                                                                samples=test_array_sampling,
                                                                e = e)
                list_metrics_shap['instability']= instability(model=model.predict, 
                                                                explainer = get_explainations,
                                                                samples=test_array_sampling,
                                                                e = e)
                
                list_metrics_shap['alpha'] = alpha
                list_metrics_shap['upper'] = upper
                list_metrics_shap['sequence_length'] = sequence_length
                list_metrics_shap['explainer'] = 'shap'
                # list_metrics_shap['model'] = model_name

                df_metrics = pd.concat([df_metrics, pd.DataFrame([list_metrics_shap])])
                
                # L2X
                e = L2X(model.predict, test_array_sampling)
                l2xvalues = get_explainations(test_array_sampling, e, L2X=True)
                l2xvalues.shape

                # L2X's metrics
                list_metrics_l2x = {}
                l2x_dist = pd.DataFrame(squareform(pdist(l2xvalues))) # Lime values explanation matrix

                list_metrics_l2x['identity'] = identity(X_dist, l2x_dist)
                list_metrics_l2x['separability'] = separability(X_dist, l2x_dist)
                list_metrics_l2x['stability'] = stability(X_dist, l2x_dist)
                list_metrics_l2x['coherence'], list_metrics_l2x['completness'], list_metrics_l2x['congruence'] = coherence(model=model.predict, explainer = get_explainations,
                                                            samples=test_array_sampling, targets=label_array_sampling, e = e, L2X=True)
                list_metrics_l2x['selectivity'] = selectivity(model=model.predict, explainer = get_explainations,
                                                samples=test_array_sampling, e_x=e, L2X=True)
                list_metrics_l2x['accumen'] = acumen(get_explainations, test_array_sampling, e=e, L2X=True)
                list_metrics_l2x['Verm_stability'] = stability_Velmurugan(get_explainations, test_array_sampling,
                                                                            e=e, top_features=200, L2X=True)
                list_metrics_l2x['fidelity'], list_metrics_l2x['sparsity']= fidelity(model=model.predict, 
                                                                explainer = get_explainations,
                                                                samples=test_array_sampling,
                                                                e = e, L2X=True)
                list_metrics_l2x['instability'] = instability(model=model.predict, 
                                                                explainer = get_explainations,
                                                                samples=test_array_sampling,
                                                                e = e, L2X=True)
                
                list_metrics_l2x['alpha'] = alpha
                list_metrics_l2x['upper'] = upper
                list_metrics_l2x['sequence_length'] = sequence_length
                list_metrics_l2x['explainer'] = 'l2x'
                # list_metrics_l2x['model'] = model_name


                df_metrics = pd.concat([df_metrics, pd.DataFrame([list_metrics_l2x])])
    df_metrics.to_csv('fd001_result/quality_by_layerl43.csv')
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# (40, 0.5, 125)
# ...
# WARNING:tensorflow:From c:\ProgramData\anaconda3\envs\tensorflow_env\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# (16731, 40, 14) (16731, 1) (100, 40, 14)
# WARNING:tensorflow:From c:\ProgramData\anaconda3\envs\tensorflow_env\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 4/4 [==============================] - 1s 7ms/step
# (5, 40, 14) (5, 1)
# 157/157 [==============================] - 3s 21ms/step
# 157/157 [==============================] - 3s 20ms/step
# 157/157 [==============================] - 3s 18ms/step
# 157/157 [==============================] - 3s 18ms/step
# 157/157 [==============================] - 3s 18ms/step
# 157/157 [==============================] - 3s 17ms/step
# 157/157 [==============================] - 3s 19ms/step
# 157/157 [==============================] - 3s 17ms/step
# 157/157 [==============================] - 3s 18ms/step
# 157/157 [==============================] - 3s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 157/157 [==============================] - 3s 19ms/step
# 18/18 [==============================] - 0s 26ms/step
# 157/157 [==============================] - 3s 18ms/step
# 18/18 [==============================] - 0s 15ms/step
# 157/157 [==============================] - 3s 20ms/step
# 18/18 [==============================] - 0s 22ms/step
# 157/157 [==============================] - 3s 17ms/step
# 18/18 [==============================] - 0s 18ms/step
# 157/157 [==============================] - 3s 19ms/step
# 18/18 [==============================] - 0s 12ms/step
# 157/157 [==============================] - 3s 17ms/step
# 157/157 [==============================] - 3s 19ms/step
# 157/157 [==============================] - 3s 20ms/step
# 157/157 [==============================] - 3s 18ms/step
# 157/157 [==============================] - 3s 19ms/step
# 157/157 [==============================] - 3s 20ms/step
# 157/157 [==============================] - 3s 17ms/step
# 157/157 [==============================] - 3s 20ms/step
# 157/157 [==============================] - 3s 20ms/step
# 157/157 [==============================] - 3s 19ms/step
# 157/157 [==============================] - 2s 10ms/step
# 10
# 157/157 [==============================] - 2s 11ms/step
# 10
# 157/157 [==============================] - 2s 11ms/step
# 10
# 157/157 [==============================] - 2s 10ms/step
# 10
# 157/157 [==============================] - 2s 10ms/step
# 10
# 157/157 [==============================] - 2s 11ms/step
# 10
# 157/157 [==============================] - 2s 11ms/step
# 10
# 157/157 [==============================] - 2s 11ms/step
# 10
# 157/157 [==============================] - 2s 10ms/step
# 10
# 157/157 [==============================] - 2s 11ms/step
# 10
# 157/157 [==============================] - 2s 10ms/step
# 10
# 157/157 [==============================] - 2s 11ms/step
# 10
# 157/157 [==============================] - 2s 10ms/step
# 10
# 157/157 [==============================] - 2s 10ms/step
# 10
# 157/157 [==============================] - 2s 10ms/step
# 10
# 157/157 [==============================] - 2s 10ms/step
# 10
# 157/157 [==============================] - 2s 11ms/step
# 10
# 157/157 [==============================] - 2s 11ms/step
# 10
# 157/157 [==============================] - 2s 10ms/step
# 10
# 157/157 [==============================] - 2s 13ms/step
# 10
# 157/157 [==============================] - 2s 12ms/step
# 10
# 157/157 [==============================] - 2s 10ms/step
# 10
# 157/157 [==============================] - 2s 10ms/step
# 10
# 157/157 [==============================] - 2s 10ms/step
# 10
# 157/157 [==============================] - 2s 12ms/step
# 10
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 157/157 [==============================] - 1s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 41ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 157/157 [==============================] - 2s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 157/157 [==============================] - 2s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 157/157 [==============================] - 2s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 157/157 [==============================] - 2s 10ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 12ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 13ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 12ms/step
# 157/157 [==============================] - 2s 11ms/step
# 157/157 [==============================] - 2s 10ms/step
# 157/157 [==============================] - 2s 11ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 19ms/step
# 18/18 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 20ms/step
# 18/18 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 20ms/step
# 18/18 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 8/8 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 8/8 [==============================] - 0s 22ms/step
# 18/18 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 24ms/step
# 8/8 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 8/8 [==============================] - 0s 29ms/step
# 18/18 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 8/8 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 18ms/step
# 10
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 10
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 10
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 20ms/step
# 10
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 23ms/step
# 10
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 22ms/step
# 12
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 12
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 22ms/step
# 12
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 12
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 21ms/step
# 12
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 21ms/step
# 10
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 10
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 10
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 21ms/step
# 10
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 10
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 21ms/step
# 10
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 21ms/step
# 10
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 10
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 10
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 23ms/step
# 10
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 23ms/step
# 10
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 23ms/step
# 10
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 21ms/step
# 10
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 10
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 21ms/step
# 10
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 8/8 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 8/8 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 8/8 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 8/8 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 8/8 [==============================] - 0s 22ms/step
# ...
# 1/1 [==============================] - 1s 615ms/step - loss: 6536.2422 - mse: 6535.4756 - val_loss: 6440.0425 - val_mse: 6439.2812
# 1/1 [==============================] - 1s 637ms/step - loss: 6403.8804 - mse: 6403.1167 - val_loss: 6370.2446 - val_mse: 6369.4854
# 1/1 [==============================] - 1s 650ms/step - loss: 6344.5132 - mse: 6343.7490 - val_loss: 6395.1191 - val_mse: 6394.3599
# 1/1 [==============================] - 1s 645ms/step - loss: 6424.0063 - mse: 6423.2393 - val_loss: 6369.7109 - val_mse: 6368.9492
# 1/1 [==============================] - 1s 612ms/step - loss: 6402.4385 - mse: 6401.6729 - val_loss: 6460.3315 - val_mse: 6459.5713
# 1/1 [==============================] - 1s 668ms/step - loss: 6434.4995 - mse: 6433.7334 - val_loss: 6452.5010 - val_mse: 6451.7397
# 1/1 [==============================] - 1s 627ms/step - loss: 6420.4185 - mse: 6419.6509 - val_loss: 6435.1860 - val_mse: 6434.4238
# 1/1 [==============================] - 1s 605ms/step - loss: 6462.0947 - mse: 6461.3291 - val_loss: 6477.7153 - val_mse: 6476.9541
# 1/1 [==============================] - 1s 645ms/step - loss: 6397.3306 - mse: 6396.5640 - val_loss: 6449.8325 - val_mse: 6449.0708
# 1/1 [==============================] - 1s 628ms/step - loss: 6403.1270 - mse: 6402.3584 - val_loss: 6400.8491 - val_mse: 6400.0850
# 1/1 [==============================] - 1s 660ms/step - loss: 6405.5156 - mse: 6404.7471 - val_loss: 6475.2261 - val_mse: 6474.4619
# 1/1 [==============================] - 1s 616ms/step - loss: 6383.6519 - mse: 6382.8872 - val_loss: 6423.4097 - val_mse: 6422.6494
# 1/1 [==============================] - 1s 629ms/step - loss: 6434.6885 - mse: 6433.9229 - val_loss: 6314.5752 - val_mse: 6313.8140
# 1/1 [==============================] - 1s 614ms/step - loss: 6400.1147 - mse: 6399.3467 - val_loss: 6454.4341 - val_mse: 6453.6709
# 1/1 [==============================] - 1s 639ms/step - loss: 6399.5977 - mse: 6398.8330 - val_loss: 6347.0425 - val_mse: 6346.2822
# 1/1 [==============================] - 1s 616ms/step - loss: 6395.0293 - mse: 6394.2617 - val_loss: 6361.4395 - val_mse: 6360.6758
# 1/1 [==============================] - 1s 608ms/step - loss: 6377.7925 - mse: 6377.0264 - val_loss: 6438.7480 - val_mse: 6437.9854
# 1/1 [==============================] - 1s 658ms/step - loss: 6395.6631 - mse: 6394.8975 - val_loss: 6513.2559 - val_mse: 6512.4937
# 1/1 [==============================] - 1s 626ms/step - loss: 6470.4448 - mse: 6469.6772 - val_loss: 6422.0703 - val_mse: 6421.3057
# 1/1 [==============================] - 1s 619ms/step - loss: 6434.4424 - mse: 6433.6782 - val_loss: 6460.5254 - val_mse: 6459.7646
# 1/1 [==============================] - 1s 612ms/step - loss: 6454.3706 - mse: 6453.6006 - val_loss: 6368.0410 - val_mse: 6367.2744
# 1/1 [==============================] - 1s 615ms/step - loss: 6418.2690 - mse: 6417.5054 - val_loss: 6534.6606 - val_mse: 6533.8999
# 1/1 [==============================] - 1s 621ms/step - loss: 6452.7026 - mse: 6451.9355 - val_loss: 6452.8828 - val_mse: 6452.1191
# 1/1 [==============================] - 1s 627ms/step - loss: 6357.9253 - mse: 6357.1641 - val_loss: 6425.1338 - val_mse: 6424.3760
# 1/1 [==============================] - 1s 651ms/step - loss: 6452.6655 - mse: 6451.8975 - val_loss: 6415.6055 - val_mse: 6414.8408
# 1/1 [==============================] - 1s 621ms/step - loss: 6441.1050 - mse: 6440.3384 - val_loss: 6459.1943 - val_mse: 6458.4312
# 1/1 [==============================] - 1s 597ms/step - loss: 6365.8193 - mse: 6365.0518 - val_loss: 6473.6729 - val_mse: 6472.9087
# 1/1 [==============================] - 1s 598ms/step - loss: 6371.9897 - mse: 6371.2217 - val_loss: 6386.5693 - val_mse: 6385.8042
# 1/1 [==============================] - 1s 658ms/step - loss: 6509.6548 - mse: 6508.8882 - val_loss: 6412.8364 - val_mse: 6412.0732
# 1/1 [==============================] - 1s 607ms/step - loss: 6489.7646 - mse: 6488.9951 - val_loss: 6343.3433 - val_mse: 6342.5771
# 1/1 [==============================] - 1s 603ms/step - loss: 6323.8970 - mse: 6323.1313 - val_loss: 6488.7407 - val_mse: 6487.9780
# 1/1 [==============================] - 1s 604ms/step - loss: 6477.7798 - mse: 6477.0132 - val_loss: 6473.9761 - val_mse: 6473.2124
# 1/1 [==============================] - 1s 610ms/step - loss: 6381.5713 - mse: 6380.8047 - val_loss: 6485.7725 - val_mse: 6485.0088
# 1/1 [==============================] - 1s 614ms/step - loss: 6419.3311 - mse: 6418.5635 - val_loss: 6401.1655 - val_mse: 6400.4004
# 1/1 [==============================] - 1s 654ms/step - loss: 6403.1729 - mse: 6402.4053 - val_loss: 6284.0103 - val_mse: 6283.2456
# 1/1 [==============================] - 1s 597ms/step - loss: 6328.8481 - mse: 6328.0840 - val_loss: 6416.4150 - val_mse: 6415.6533
# 1/1 [==============================] - 1s 627ms/step - loss: 6451.7061 - mse: 6450.9351 - val_loss: 6366.7764 - val_mse: 6366.0078
# 1/1 [==============================] - 1s 639ms/step - loss: 6449.0854 - mse: 6448.3203 - val_loss: 6428.7969 - val_mse: 6428.0342
# 1/1 [==============================] - 1s 604ms/step - loss: 6433.5562 - mse: 6432.7900 - val_loss: 6410.3032 - val_mse: 6409.5396
# 1/1 [==============================] - 1s 630ms/step - loss: 6441.1821 - mse: 6440.4165 - val_loss: 6447.7197 - val_mse: 6446.9561
# 1/1 [==============================] - 1s 649ms/step - loss: 6427.0146 - mse: 6426.2510 - val_loss: 6439.4355 - val_mse: 6438.6743
# 1/1 [==============================] - 1s 598ms/step - loss: 6419.4019 - mse: 6418.6377 - val_loss: 6556.4946 - val_mse: 6555.7319
# 1/1 [==============================] - 1s 617ms/step - loss: 6324.6777 - mse: 6323.9121 - val_loss: 6341.6060 - val_mse: 6340.8428
# 1/1 [==============================] - 1s 647ms/step - loss: 6479.5239 - mse: 6478.7593 - val_loss: 6486.5830 - val_mse: 6485.8203
# 1/1 [==============================] - 1s 654ms/step - loss: 6445.3682 - mse: 6444.6040 - val_loss: 6452.6499 - val_mse: 6451.8882
# 1/1 [==============================] - 1s 589ms/step - loss: 6474.6987 - mse: 6473.9316 - val_loss: 6373.6431 - val_mse: 6372.8774
# 1/1 [==============================] - 1s 607ms/step - loss: 6439.9424 - mse: 6439.1782 - val_loss: 6458.2554 - val_mse: 6457.4932
# 1/1 [==============================] - 1s 644ms/step - loss: 6429.5298 - mse: 6428.7642 - val_loss: 6351.6533 - val_mse: 6350.8896
# 1/1 [==============================] - 1s 603ms/step - loss: 6409.2100 - mse: 6408.4429 - val_loss: 6379.4531 - val_mse: 6378.6880
# 1/1 [==============================] - 1s 597ms/step - loss: 6462.3174 - mse: 6461.5513 - val_loss: 6478.5898 - val_mse: 6477.8257
# 1/1 [==============================] - 1s 620ms/step - loss: 6405.3579 - mse: 6404.5908 - val_loss: 6490.3950 - val_mse: 6489.6299
# 1/1 [==============================] - 1s 614ms/step - loss: 6434.6089 - mse: 6433.8442 - val_loss: 6300.2988 - val_mse: 6299.5361
# 1/1 [==============================] - 1s 610ms/step - loss: 6485.3936 - mse: 6484.6279 - val_loss: 6377.0283 - val_mse: 6376.2646
# 1/1 [==============================] - 1s 651ms/step - loss: 6460.1719 - mse: 6459.4067 - val_loss: 6422.6372 - val_mse: 6421.8735
# 1/1 [==============================] - 1s 610ms/step - loss: 6419.7412 - mse: 6418.9736 - val_loss: 6261.6445 - val_mse: 6260.8789
# 1/1 [==============================] - 1s 614ms/step - loss: 6416.1255 - mse: 6415.3604 - val_loss: 6533.6265 - val_mse: 6532.8633
# 1/1 [==============================] - 1s 642ms/step - loss: 6435.0039 - mse: 6434.2373 - val_loss: 6369.6211 - val_mse: 6368.8564
# 1/1 [==============================] - 1s 615ms/step - loss: 6314.1382 - mse: 6313.3745 - val_loss: 6372.1646 - val_mse: 6371.4028
# 1/1 [==============================] - 1s 617ms/step - loss: 6405.2207 - mse: 6404.4546 - val_loss: 6358.5552 - val_mse: 6357.7900
# 1/1 [==============================] - 1s 601ms/step - loss: 6339.7417 - mse: 6338.9736 - val_loss: 6394.9551 - val_mse: 6394.1885
# 1/1 [==============================] - 1s 655ms/step - loss: 6409.9800 - mse: 6409.2144 - val_loss: 6350.6567 - val_mse: 6349.8931
# 1/1 [==============================] - 1s 615ms/step - loss: 6511.7148 - mse: 6510.9468 - val_loss: 6368.4131 - val_mse: 6367.6465
# 1/1 [==============================] - 1s 602ms/step - loss: 6425.5229 - mse: 6424.7563 - val_loss: 6479.7666 - val_mse: 6479.0015
# 1/1 [==============================] - 1s 686ms/step - loss: 6453.8481 - mse: 6453.0845 - val_loss: 6520.2065 - val_mse: 6519.4443
# 1/1 [==============================] - 1s 599ms/step - loss: 6363.9707 - mse: 6363.2056 - val_loss: 6349.6968 - val_mse: 6348.9326
# 1/1 [==============================] - 1s 615ms/step - loss: 6405.7314 - mse: 6404.9683 - val_loss: 6389.9072 - val_mse: 6389.1455
# 1/1 [==============================] - 1s 627ms/step - loss: 6409.9834 - mse: 6409.2188 - val_loss: 6313.8335 - val_mse: 6313.0703
# 1/1 [==============================] - 1s 603ms/step - loss: 6462.9336 - mse: 6462.1699 - val_loss: 6307.9722 - val_mse: 6307.2100
# 1/1 [==============================] - 1s 608ms/step - loss: 6415.1099 - mse: 6414.3428 - val_loss: 6453.2358 - val_mse: 6452.4702
# 1/1 [==============================] - 1s 638ms/step - loss: 6400.0186 - mse: 6399.2510 - val_loss: 6373.5093 - val_mse: 6372.7432
# 1/1 [==============================] - 1s 617ms/step - loss: 6408.1709 - mse: 6407.4048 - val_loss: 6391.6826 - val_mse: 6390.9170
# 1/1 [==============================] - 1s 610ms/step - loss: 6381.2070 - mse: 6380.4399 - val_loss: 6306.6958 - val_mse: 6305.9302
# 1/1 [==============================] - 1s 633ms/step - loss: 6439.7681 - mse: 6439.0029 - val_loss: 6479.3550 - val_mse: 6478.5908
# 1/1 [==============================] - 1s 659ms/step - loss: 6386.6270 - mse: 6385.8584 - val_loss: 6416.2285 - val_mse: 6415.4614
# 1/1 [==============================] - 1s 643ms/step - loss: 6365.8735 - mse: 6365.1064 - val_loss: 6361.0259 - val_mse: 6360.2603
# 1/1 [==============================] - 1s 612ms/step - loss: 6405.2695 - mse: 6404.5034 - val_loss: 6306.0098 - val_mse: 6305.2451
# 1/1 [==============================] - 1s 614ms/step - loss: 6457.7451 - mse: 6456.9775 - val_loss: 6315.6270 - val_mse: 6314.8604
# 1/1 [==============================] - 1s 641ms/step - loss: 6451.4785 - mse: 6450.7109 - val_loss: 6377.6421 - val_mse: 6376.8760
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# 18/18 [==============================] - 0s 10ms/step
# 18/18 [==============================] - 0s 10ms/step
# 18/18 [==============================] - 0s 11ms/step
# 18/18 [==============================] - 0s 10ms/step
# 18/18 [==============================] - 0s 10ms/step
# 11
# 11
# 11
# 11
# 11
# 16
# 16
# 16
# 16
# 16
# 10
# 10
# 10
# 10
# 10
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 275ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 357ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 100%|██████████| 2/2 [6:13:48<00:00, 11214.46s/it]

# %%
# (40, 0.5, 125)
